# %%
# Replace this with your GitHub Personal Access Token (PAT)
personal_access_token = ""

# Clone the private repo using the token
# !git clone https://{personal_access_token}@github.com/AliMuhammadAsad/PAN2025-MultiAuthor-LLMs-Project.git
# Out:
# Cloning into 'PAN2025-MultiAuthor-LLMs-Project'...
# remote: Enumerating objects: 24927, done.
# remote: Counting objects: 100% (2506/2506), done.
# remote: Compressing objects: 100% (292/292), done.
# remote: Total 24927 (delta 2420), reused 2289 (delta 2206), pack-reused 22421 (from 1)
# Receiving objects: 100% (24927/24927), 27.69 MiB | 8.03 MiB/s, done.
# Resolving deltas: 100% (4492/4492), done.
# Updating files: 100% (124256/124256), done.

# %%
# !pip install transformers torch
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 35.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 44.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 23.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 19.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 86.0 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# !pip install -U bitsandbytes optimum peft --break-system-packages
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl.metadata (5.0 kB)
# Collecting optimum
#   Downloading optimum-1.24.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (0.14.0)
# Collecting peft
#   Downloading peft-0.15.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: torch<3,>=2.0 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: transformers>=4.29 in /usr/local/lib/python3.11/dist-packages (from optimum) (4.51.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from optimum) (24.2)
# Requirement already satisfied: huggingface-hub>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from optimum) (0.30.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from peft) (6.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from peft) (4.67.1)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from peft) (1.5.2)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from peft) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.8.0->optimum) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.8.0->optimum) (2025.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.8.0->optimum) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.8.0->optimum) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2.0->bitsandbytes) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.29->optimum) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.29->optimum) (0.21.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.0->bitsandbytes) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.8.0->optimum) (2025.1.31)
# Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl (76.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 8.7 MB/s eta 0:00:00
# Downloading optimum-1.24.0-py3-none-any.whl (433 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 433.6/433.6 kB 17.4 MB/s eta 0:00:00
# Downloading peft-0.15.2-py3-none-any.whl (411 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.1/411.1 kB 19.5 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes, peft, optimum
#   Attempting uninstall: peft
#     Found existing installation: peft 0.14.0
#     Uninstalling peft-0.14.0:
#       Successfully uninstalled peft-0.14.0
# Successfully installed bitsandbytes-0.45.5 optimum-1.24.0 peft-0.15.2

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: fineGrained).
# The token `llama3.2-phirse` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `llama3.2-phirse`

# %%
# Importing necessary libraries
import os
import json
import torch
from transformers import ElectraTokenizer, ElectraForSequenceClassification
from transformers import Trainer, TrainingArguments
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from torch.utils.data import Dataset

# Check if CUDA is available and use GPU if possible
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
# Dataset Loading Function (same as before)
def load_dataset(base_path):
    levels = ['easy', 'medium', 'hard']
    splits = ['train', 'validation']
    dataset = {}

    for level in levels:
        dataset[level] = {}
        for split in splits:
            split_path = os.path.join(base_path, level, split)
            documents = []

            for filename in sorted(os.listdir(split_path)):
                if filename.startswith('problem-') and filename.endswith('.txt'):
                    problem_id = filename.split('.')[0]
                    txt_path = os.path.join(split_path, filename)
                    json_path = os.path.join(split_path, f'truth-{problem_id}.json')

                    with open(txt_path, 'r', encoding='utf-8') as f:
                        sentences = [line.strip() for line in f.readlines() if line.strip()]

                    with open(json_path, 'r', encoding='utf-8') as f:
                        truth = json.load(f)
                        changes = truth['changes']

                    documents.append((sentences, changes, problem_id))

            dataset[level][split] = documents

    return dataset

# Prepare ELECTRA data function (same logic)
def prepare_bert_data(documents, tokenizer, max_length=256):
    inputs = {'input_ids': [], 'attention_mask': []}
    labels = []
    problem_ids_with_offsets = []

    for sentences, changes, problem_id in documents:
        for i in range(len(changes)):
            pair_text = sentences[i] + ' ' + sentences[i + 1]
            encoded = tokenizer(pair_text, truncation=True, padding='max_length', max_length=max_length, return_tensors='pt')
            inputs['input_ids'].append(encoded['input_ids'].squeeze())
            inputs['attention_mask'].append(encoded['attention_mask'].squeeze())
            labels.append(changes[i])
            problem_ids_with_offsets.append((problem_id, i, len(labels) - 1))

    return inputs, labels, problem_ids_with_offsets

# Custom Dataset (same)
class CustomDataset(Dataset):
    def __init__(self, inputs, labels):
        self.inputs = inputs
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        item = {key: val[idx] for key, val in self.inputs.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

# Plot Confusion Matrix (same)
def plot_confusion_matrix(y_true, y_pred, title):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
                xticklabels=['No Change (0)', 'Change (1)'],
                yticklabels=['No Change (0)', 'Change (1)'])
    plt.title(title)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()
    return cm

# Save Predictions to JSON (same)
def save_predictions_to_json(predictions, problem_ids_with_offsets, output_base_path, level, split):
    output_dir = os.path.join(output_base_path, level)
    os.makedirs(output_dir, exist_ok=True)

    pred_dict = {}
    for pred, (problem_id, idx, offset) in zip(predictions, problem_ids_with_offsets):
        if problem_id not in pred_dict:
            pred_dict[problem_id] = []
        pred_dict[problem_id].append(int(pred))

    for problem_id, changes in pred_dict.items():
        solution = {"changes": changes}
        output_path = os.path.join(output_dir, f'solution-{problem_id}.json')
        with open(output_path, 'w', encoding='utf-8') as f:
            json.dump(solution, f, indent=4)
        print(f"Saved: {output_path}")

# Train and evaluate with ELECTRA
def train_and_evaluate_electra(train_inputs, train_labels, val_inputs, val_labels, val_problem_ids_with_offsets, level, output_base_path):
    model_name = "google/electra-base-discriminator"
    tokenizer = ElectraTokenizer.from_pretrained(model_name)
    model = ElectraForSequenceClassification.from_pretrained(model_name, num_labels=2)

    model.to(device)

    train_dataset = CustomDataset(train_inputs, train_labels)
    val_dataset = CustomDataset(val_inputs, val_labels)

    training_args = TrainingArguments(
        output_dir="./results",
        num_train_epochs=1,
        per_device_train_batch_size=4,
        per_device_eval_batch_size=4,
        eval_strategy="epoch",
        logging_dir='./logs',
        fp16=True,
    )

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=val_dataset,
        compute_metrics=lambda p: {
            'accuracy': accuracy_score(p.label_ids, p.predictions.argmax(axis=-1))
        }
    )

    print("Starting training...")
    trainer.train()
    print("Training done")

    val_pred = trainer.predict(val_dataset).predictions.argmax(axis=-1)

    accuracy = accuracy_score(val_labels, val_pred)
    f1 = f1_score(val_labels, val_pred)

    print(f"\n{level} Level Metrics:")
    print(f"Accuracy: {accuracy:.4f}, F1-Score: {f1:.4f}")
    print("Classification Report:")
    print(classification_report(val_labels, val_pred, target_names=['No Change (0)', 'Change (1)']))

    cm = plot_confusion_matrix(val_labels, val_pred, f'Confusion Matrix - {level} Level')
    save_predictions_to_json(val_pred, val_problem_ids_with_offsets, output_base_path, level, 'validation')

    return model, tokenizer, val_pred, cm

# Set up dataset path
dataset_dir = "PAN2025-MultiAuthor-LLMs-Project/dataset"
print("Loading dataset...")
dataset = load_dataset(dataset_dir)

output_path = "../outputs_electra"

all_val_y = []
all_val_pred = []
all_cm = None
levels = ["easy", "medium", "hard"]

for level in levels:
    print(f"Processing {level} level...")

    train_docs = dataset[level]['train']
    val_docs = dataset[level]['validation']

    tokenizer = ElectraTokenizer.from_pretrained("google/electra-small-discriminator")

    train_inputs, train_labels, _ = prepare_bert_data(train_docs, tokenizer)
    val_inputs, val_labels, val_problem_ids_with_offsets = prepare_bert_data(val_docs, tokenizer)

    model, tokenizer, val_pred, cm = train_and_evaluate_electra(train_inputs, train_labels, val_inputs, val_labels, val_problem_ids_with_offsets, level, output_path)

    all_val_y.extend(val_labels)
    all_val_pred.extend(val_pred)
    if all_cm is None:
        all_cm = cm
    else:
        all_cm += cm

print("\nCombined Metrics Across All Levels:")
print("Classification Report:")
print(classification_report(all_val_y, all_val_pred, target_names=['No Change (0)', 'Change (1)']))
plot_confusion_matrix(all_val_y, all_val_pred, 'Combined Confusion Matrix - All Levels')

# Save final model
model_dir = "../models_electra"
os.makedirs(model_dir, exist_ok=True)
model.save_pretrained(model_dir)
tokenizer.save_pretrained(model_dir)
# Out:
# Loading dataset...
# Processing easy level...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at google/electra-base-discriminator and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# Starting training...
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: aa07190 (aa07190-habib-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/content/wandb/run-20250422_103040-h0q9jzca</code>
# Syncing run <strong><a href='https://wandb.ai/aa07190-habib-university/huggingface/runs/h0q9jzca' target="_blank">./results</a></strong> to <a href='https://wandb.ai/aa07190-habib-university/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/aa07190-habib-university/huggingface' target="_blank">https://wandb.ai/aa07190-habib-university/huggingface</a>
#  View run at <a href='https://wandb.ai/aa07190-habib-university/huggingface/runs/h0q9jzca' target="_blank">https://wandb.ai/aa07190-habib-university/huggingface/runs/h0q9jzca</a>
#     <div>
#
#       <progress value='16' max='12101' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [   16/12101 02:57 < 42:28:01, 0.08 it/s, Epoch 0.00/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-fcb8d2952a6d> in <cell line: 0>()
#     179     val_inputs, val_labels, val_problem_ids_with_offsets = prepare_bert_data(val_docs, tokenizer)
#     180
# --> 181     model, tokenizer, val_pred, cm = train_and_evaluate_electra(train_inputs, train_labels, val_inputs, val_labels, val_problem_ids_with_offsets, level, output_path)
#     182
#     183     all_val_y.extend(val_labels)
#
# <ipython-input-5-fcb8d2952a6d> in train_and_evaluate_electra(train_inputs, train_labels, val_inputs, val_labels, val_problem_ids_with_offsets, level, output_base_path)
#     138
#     139     print("Starting training...")
# --> 140     trainer.train()
#     141     print("Training done")
#     142
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2243                 hf_hub_utils.enable_progress_bars()
#    2244         else:
# -> 2245             return inner_training_loop(
#    2246                 args=args,
#    2247                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2558                     )
#    2559                     with context():
# -> 2560                         tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2561
#    2562                     if (
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in training_step(self, model, inputs, num_items_in_batch)
#    3734
#    3735         with self.compute_loss_context_manager():
# -> 3736             loss = self.compute_loss(model, inputs, num_items_in_batch=num_items_in_batch)
#    3737
#    3738         del inputs
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in compute_loss(self, model, inputs, return_outputs, num_items_in_batch)
#    3799                 loss_kwargs["num_items_in_batch"] = num_items_in_batch
#    3800             inputs = {**inputs, **loss_kwargs}
# -> 3801         outputs = model(**inputs)
#    3802         # Save past state if it exists
#    3803         # TODO: this needs to be fixed and made cleaner later.
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/electra/modeling_electra.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#     994         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#     995
# --> 996         discriminator_hidden_states = self.electra(
#     997             input_ids,
#     998             attention_mask=attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/electra/modeling_electra.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     908             hidden_states = self.embeddings_project(hidden_states)
#     909
# --> 910         hidden_states = self.encoder(
#     911             hidden_states,
#     912             attention_mask=extended_attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/electra/modeling_electra.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     581                 )
#     582             else:
# --> 583                 layer_outputs = layer_module(
#     584                     hidden_states,
#     585                     attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/electra/modeling_electra.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     470         # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     471         self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 472         self_attention_outputs = self.attention(
#     473             hidden_states,
#     474             attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/electra/modeling_electra.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     397         output_attentions: Optional[bool] = False,
#     398     ) -> Tuple[torch.Tensor]:
# --> 399         self_outputs = self.self(
#     400             hidden_states,
#     401             attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/electra/modeling_electra.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     270         else:
#     271             key_layer = self.transpose_for_scores(self.key(hidden_states))
# --> 272             value_layer = self.transpose_for_scores(self.value(hidden_states))
#     273
#     274         query_layer = self.transpose_for_scores(mixed_query_layer)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     123
#     124     def forward(self, input: Tensor) -> Tensor:
# --> 125         return F.linear(input, self.weight, self.bias)
#     126
#     127     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
# !zip -r /content/file.zip /content/PAN2025-MultiAuthor-LLMs-Project/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/dataset/hard/truth-problem-638.json (deflated 41%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/dataset/hard/truth-problem-300.json (deflated 34%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/dataset/hard/truth-problem-843.json (deflated 34%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/dataset/hard/truth-problem-178.json (deflated 47%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/dataset/hard/truth-problem-687.json (deflated 43%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/dataset/hard/truth-problem-676.json (deflated 55%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/dataset/hard/truth-problem-516.json (deflated 31%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/dataset/hard/truth-problem-885.json (deflated 43%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/dataset/hard/truth-problem-182.json (deflated 44%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/dataset/hard/truth-problem-291.json (deflated 52%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/dataset/hard/truth-problem-582.json (deflated 59%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/dataset/hard/truth-problem-326.json (deflated 34%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/dataset/hard/truth-problem-379.json (deflated 29%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/dataset/hard/truth-problem-420.json (deflated 33%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/dataset/hard/truth-problem-425.json (deflated 54%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/dataset/hard/truth-problem-407.json (deflated 52%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/dataset/hard/truth-problem-114.json (deflated 47%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/dataset/hard/truth-problem-226.json (deflated 55%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/dataset/hard/truth-problem-712.json (deflated 25%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/dataset/hard/truth-problem-488.json (deflated 42%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/dataset/hard/truth-problem
)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/outputs_bow/hard/solution-problem-424.json (deflated 86%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/outputs_bow/hard/solution-problem-816.json (deflated 80%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/outputs_bow/hard/solution-problem-744.json (deflated 77%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/outputs_bow/hard/solution-problem-679.json (deflated 71%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/outputs_bow/hard/solution-problem-186.json (deflated 82%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/outputs_bow/hard/solution-problem-515.json (deflated 70%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/outputs_bow/hard/solution-problem-550.json (deflated 79%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/optim_bow_eval/ (stored 0%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/optim_bow_eval/evaluation.prototext (deflated 46%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/bow_eval/ (stored 0%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/bow_eval/evaluation.prototext (deflated 47%)
#   adding: content/PAN2025-MultiAuthor-LLMs-Project/evaluate/evaluator.py (deflated 71%)

# %%
from google.colab import files
files.download("/content/file.zip")

# %%
# !ls ../
# Out:
# bin			    kaggle  NGC-DL-CONTAINER-LICENSE  sbin
# boot			    lib     opt			      srv
# content			    lib32   outputs_distilbert	      sys
# cuda-keyring_1.1-1_all.deb  lib64   proc		      tmp
# datalab			    libx32  python-apt		      tools
# dev			    media   python-apt.tar.xz	      usr
# etc			    mnt     root		      var
# home			    models  run

# %%
# Now zip and downlaod the outputs of distilbert and the distilbert model files

# !zip -r /content/outputs_distilbert.zip ../outputs_distilbert/
# Out:
#   adding: ../outputs_distilbert/ (stored 0%)
#   adding: ../outputs_distilbert/easy/ (stored 0%)
#   adding: ../outputs_distilbert/easy/solution-problem-331.json (deflated 71%)
#   adding: ../outputs_distilbert/easy/solution-problem-268.json (deflated 82%)
#   adding: ../outputs_distilbert/easy/solution-problem-864.json (deflated 55%)
#   adding: ../outputs_distilbert/easy/solution-problem-792.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-356.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-27.json (deflated 70%)
#   adding: ../outputs_distilbert/easy/solution-problem-282.json (deflated 85%)
#   adding: ../outputs_distilbert/easy/solution-problem-562.json (deflated 49%)
#   adding: ../outputs_distilbert/easy/solution-problem-113.json (deflated 66%)
#   adding: ../outputs_distilbert/easy/solution-problem-172.json (deflated 71%)
#   adding: ../outputs_distilbert/easy/solution-problem-796.json (deflated 72%)
#   adding: ../outputs_distilbert/easy/solution-problem-739.json (deflated 69%)
#   adding: ../outputs_distilbert/easy/solution-problem-200.json (deflated 79%)
#   adding: ../outputs_distilbert/easy/solution-problem-479.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-43.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-654.json (deflated 81%)
#   adding: ../outputs_distilbert/easy/solution-problem-153.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-117.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-293.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-495.json (deflated 79%)
#   adding: ../outputs_distilbert/easy/solution-problem-329.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-721.json (deflated 80%)
#   adding: ../outputs_distilbert/easy/solution-problem-787.json (deflated 69%)
#   adding: ../outputs_distilbert/easy/solution-problem-673.json (deflated 82%)
#   adding: ../outputs_distilbert/easy/solution-problem-148.json (deflated 63%)
#   adding: ../outputs_distilbert/easy/solution-problem-431.json (deflated 65%)
#   adding: ../outputs_distilbert/easy/solution-problem-780.json (deflated 70%)
#   adding: ../outputs_distilbert/easy/solution-problem-453.json (deflated 63%)
#   adding: ../outputs_distilbert/easy/solution-problem-52.json (deflated 68%)
#   adding: ../outputs_distilbert/easy/solution-problem-657.json (deflated 72%)
#   adding: ../outputs_distilbert/easy/solution-problem-558.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-900.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-284.json (deflated 80%)
#   adding: ../outputs_distilbert/easy/solution-problem-860.json (deflated 72%)
#   adding: ../outputs_distilbert/easy/solution-problem-689.json (deflated 61%)
#   adding: ../outputs_distilbert/easy/solution-problem-529.json (deflated 78%)
#   adding: ../outputs_distilbert/easy/solution-problem-132.json (deflated 72%)
#   adding: ../outputs_distilbert/easy/solution-problem-316.json (deflated 74%)
#   adding: ../outputs_distilbert/easy/solution-problem-737.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-785.json (deflated 70%)
#   adding: ../outputs_distilbert/easy/solution-problem-205.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-59.json (deflated 80%)
#   adding: ../outputs_distilbert/easy/solution-problem-267.json (deflated 84%)
#   adding: ../outputs_distilbert/easy/solution-problem-831.json (deflated 74%)
#   adding: ../outputs_distilbert/easy/solution-problem-809.json (deflated 60%)
#   adding: ../outputs_distilbert/easy/solution-problem-274.json (deflated 71%)
#   adding: ../outputs_distilbert/easy/solution-problem-173.json (deflated 79%)
#   adding: ../outputs_distilbert/easy/solution-problem-836.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-127.json (deflated 80%)
#   adding: ../outputs_distilbert/easy/solution-problem-106.json (deflated 69%)
#   adding: ../outputs_distilbert/easy/solution-problem-611.json (deflated 79%)
#   adding: ../outputs_distilbert/easy/solution-problem-877.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-422.json (deflated 58%)
#   adding: ../outputs_distilbert/easy/solution-problem-341.json (deflated 76%)
#   adding: ../outputs_distilbert/easy/solution-problem-604.json (deflated 83%)
#   adding: ../outputs_distilbert/easy/solution-problem-488.json (deflated 80%)
#   adding: ../outputs_distilbert/easy/solution-problem-814.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-575.json (deflated 79%)
#   adding: ../outputs_distilbert/easy/solution-problem-617.json (deflated 80%)
#   adding: ../outputs_distilbert/easy/solution-problem-389.json (deflated 64%)
#   adding: ../outputs_distilbert/easy/solution-problem-61.json (deflated 72%)
#   adding: ../outputs_distilbert/easy/solution-problem-875.json (deflated 82%)
#   adding: ../outputs_distilbert/easy/solution-problem-730.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-733.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-221.json (deflated 74%)
#   adding: ../outputs_distilbert/easy/solution-problem-830.json (deflated 74%)
#   adding: ../outputs_distilbert/easy/solution-problem-754.json (deflated 80%)
#   adding: ../outputs_distilbert/easy/solution-problem-369.json (deflated 43%)
#   adding: ../outputs_distilbert/easy/solution-problem-817.json (deflated 83%)
#   adding: ../outputs_distilbert/easy/solution-problem-380.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-543.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-263.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-17.json (deflated 74%)
#   adding: ../outputs_distilbert/easy/solution-problem-202.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-764.json (deflated 68%)
#   adding: ../outputs_distilbert/easy/solution-problem-403.json (deflated 82%)
#   adding: ../outputs_distilbert/easy/solution-problem-467.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-109.json (deflated 58%)
#   adding: ../outputs_distilbert/easy/solution-problem-772.json (deflated 79%)
#   adding: ../outputs_distilbert/easy/solution-problem-590.json (deflated 69%)
#   adding: ../outputs_distilbert/easy/solution-problem-392.json (deflated 79%)
#   adding: ../outputs_distilbert/easy/solution-problem-729.json (deflated 68%)
#   adding: ../outputs_distilbert/easy/solution-problem-709.json (deflated 68%)
#   adding: ../outputs_distilbert/easy/solution-problem-532.json (deflated 76%)
#   adding: ../outputs_distilbert/easy/solution-problem-561.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-395.json (deflated 80%)
#   adding: ../outputs_distilbert/easy/solution-problem-79.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-325.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-41.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-134.json (deflated 81%)
#   adding: ../outputs_distilbert/easy/solution-problem-112.json (deflated 84%)
#   adding: ../outputs_distilbert/easy/solution-problem-460.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-663.json (deflated 79%)
#   adding: ../outputs_distilbert/easy/solution-problem-312.json (deflated 57%)
#   adding: ../outputs_distilbert/easy/solution-problem-35.json (deflated 84%)
#   adding: ../outputs_distilbert/easy/solution-problem-463.json (deflated 78%)
#   adding: ../outputs_distilbert/easy/solution-problem-208.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-726.json (deflated 71%)
#   adding: ../outputs_distilbert/easy/solution-problem-281.json (deflated 78%)
#   adding: ../outputs_distilbert/easy/solution-problem-461.json (deflated 72%)
#   adding: ../outputs_distilbert/easy/solution-problem-701.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-770.json (deflated 78%)
#   adding: ../outputs_distilbert/easy/solution-problem-837.json (deflated 81%)
#   adding: ../outputs_distilbert/easy/solution-problem-781.json (deflated 78%)
#   adding: ../outputs_distilbert/easy/solution-problem-4.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-645.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-714.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-621.json (deflated 70%)
#   adding: ../outputs_distilbert/easy/solution-problem-790.json (deflated 82%)
#   adding: ../outputs_distilbert/easy/solution-problem-615.json (deflated 76%)
#   adding: ../outputs_distilbert/easy/solution-problem-458.json (deflated 85%)
#   adding: ../outputs_distilbert/easy/solution-problem-414.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-244.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-530.json (deflated 79%)
#   adding: ../outputs_distilbert/easy/solution-problem-719.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-638.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-518.json (deflated 81%)
#   adding: ../outputs_distilbert/easy/solution-problem-783.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-111.json (deflated 69%)
#   adding: ../outputs_distilbert/easy/solution-problem-698.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-647.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-418.json (deflated 71%)
#   adding: ../outputs_distilbert/easy/solution-problem-270.json (deflated 66%)
#   adding: ../outputs_distilbert/easy/solution-problem-315.json (deflated 81%)
#   adding: ../outputs_distilbert/easy/solution-problem-457.json (deflated 63%)
#   adding: ../outputs_distilbert/easy/solution-problem-452.json (deflated 60%)
#   adding: ../outputs_distilbert/easy/solution-problem-421.json (deflated 83%)
#   adding: ../outputs_distilbert/easy/solution-problem-579.json (deflated 72%)
#   adding: ../outputs_distilbert/easy/solution-problem-66.json (deflated 82%)
#   adding: ../outputs_distilbert/easy/solution-problem-516.json (deflated 61%)
#   adding: ../outputs_distilbert/easy/solution-problem-520.json (deflated 83%)
#   adding: ../outputs_distilbert/easy/solution-problem-763.json (deflated 74%)
#   adding: ../outputs_distilbert/easy/solution-problem-68.json (deflated 71%)
#   adding: ../outputs_distilbert/easy/solution-problem-626.json (deflated 72%)
#   adding: ../outputs_distilbert/easy/solution-problem
json (deflated 80%)
#   adding: ../outputs_distilbert/easy/solution-problem-885.json (deflated 67%)
#   adding: ../outputs_distilbert/easy/solution-problem-842.json (deflated 76%)
#   adding: ../outputs_distilbert/easy/solution-problem-55.json (deflated 80%)
#   adding: ../outputs_distilbert/easy/solution-problem-806.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-456.json (deflated 81%)
#   adding: ../outputs_distilbert/easy/solution-problem-888.json (deflated 83%)
#   adding: ../outputs_distilbert/easy/solution-problem-104.json (deflated 76%)
#   adding: ../outputs_distilbert/easy/solution-problem-849.json (deflated 68%)
#   adding: ../outputs_distilbert/easy/solution-problem-708.json (deflated 70%)
#   adding: ../outputs_distilbert/easy/solution-problem-69.json (deflated 68%)
#   adding: ../outputs_distilbert/easy/solution-problem-848.json (deflated 72%)
#   adding: ../outputs_distilbert/easy/solution-problem-592.json (deflated 78%)
#   adding: ../outputs_distilbert/easy/solution-problem-773.json (deflated 74%)
#   adding: ../outputs_distilbert/easy/solution-problem-169.json (deflated 72%)
#   adding: ../outputs_distilbert/easy/solution-problem-368.json (deflated 69%)
#   adding: ../outputs_distilbert/easy/solution-problem-15.json (deflated 80%)
#   adding: ../outputs_distilbert/easy/solution-problem-898.json (deflated 80%)
#   adding: ../outputs_distilbert/easy/solution-problem-834.json (deflated 79%)
#   adding: ../outputs_distilbert/easy/solution-problem-503.json (deflated 69%)
#   adding: ../outputs_distilbert/easy/solution-problem-273.json (deflated 81%)
#   adding: ../outputs_distilbert/easy/solution-problem-492.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-58.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-71.json (deflated 70%)
#   adding: ../outputs_distilbert/easy/solution-problem-600.json (deflated 52%)
#   adding: ../outputs_distilbert/easy/solution-problem-407.json (deflated 68%)
#   adding: ../outputs_distilbert/easy/solution-problem-34.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-870.json (deflated 72%)
#   adding: ../outputs_distilbert/easy/solution-problem-863.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-96.json (deflated 76%)
#   adding: ../outputs_distilbert/easy/solution-problem-602.json (deflated 80%)
#   adding: ../outputs_distilbert/easy/solution-problem-405.json (deflated 65%)
#   adding: ../outputs_distilbert/easy/solution-problem-454.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-671.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-175.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-857.json (deflated 84%)
#   adding: ../outputs_distilbert/easy/solution-problem-630.json (deflated 76%)
#   adding: ../outputs_distilbert/easy/solution-problem-133.json (deflated 64%)
#   adding: ../outputs_distilbert/easy/solution-problem-699.json (deflated 78%)
#   adding: ../outputs_distilbert/easy/solution-problem-505.json (deflated 82%)
#   adding: ../outputs_distilbert/easy/solution-problem-367.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-580.json (deflated 85%)
#   adding: ../outputs_distilbert/easy/solution-problem-401.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-102.json (deflated 82%)
#   adding: ../outputs_distilbert/easy/solution-problem-612.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-246.json (deflated 76%)
#   adding: ../outputs_distilbert/easy/solution-problem-840.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-603.json (deflated 78%)
#   adding: ../outputs_distilbert/easy/solution-problem-552.json (deflated 78%)
#   adding: ../outputs_distilbert/easy/solution-problem-607.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-28.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-788.json (deflated 69%)
#   adding: ../outputs_distilbert/easy/solution-problem-745.json (deflated 78%)
#   adding: ../outputs_distilbert/easy/solution-problem-98.json (deflated 72%)
#   adding: ../outputs_distilbert/easy/solution-problem-692.json (deflated 80%)
#   adding: ../outputs_distilbert/easy/solution-problem-797.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-171.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-442.json (deflated 74%)
#   adding: ../outputs_distilbert/easy/solution-problem-162.json (deflated 72%)
#   adding: ../outputs_distilbert/easy/solution-problem-280.json (deflated 72%)
#   adding: ../outputs_distilbert/easy/solution-problem-391.json (deflated 80%)
#   adding: ../outputs_distilbert/easy/solution-problem-588.json (deflated 80%)
#   adding: ../outputs_distilbert/easy/solution-problem-362.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-72.json (deflated 72%)
#   adding: ../outputs_distilbert/easy/solution-problem-300.json (deflated 71%)
#   adding: ../outputs_distilbert/easy/solution-problem-311.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-125.json (deflated 87%)
#   adding: ../outputs_distilbert/easy/solution-problem-384.json (deflated 62%)
#   adding: ../outputs_distilbert/easy/solution-problem-690.json (deflated 72%)
#   adding: ../outputs_distilbert/easy/solution-problem-824.json (deflated 74%)
#   adding: ../outputs_distilbert/easy/solution-problem-47.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-151.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-291.json (deflated 68%)
#   adding: ../outputs_distilbert/easy/solution-problem-859.json (deflated 70%)
#   adding: ../outputs_distilbert/easy/solution-problem-489.json (deflated 78%)
#   adding: ../outputs_distilbert/easy/solution-problem-430.json (deflated 76%)
#   adding: ../outputs_distilbert/easy/solution-problem-887.json (deflated 74%)
#   adding: ../outputs_distilbert/easy/solution-problem-865.json (deflated 79%)
#   adding: ../outputs_distilbert/easy/solution-problem-476.json (deflated 76%)
#   adding: ../outputs_distilbert/easy/solution-problem-255.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-629.json (deflated 69%)
#   adding: ../outputs_distilbert/easy/solution-problem-12.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-144.json (deflated 70%)
#   adding: ../outputs_distilbert/easy/solution-problem-8.json (deflated 71%)
#   adding: ../outputs_distilbert/easy/solution-problem-892.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-616.json (deflated 78%)
#   adding: ../outputs_distilbert/easy/solution-problem-180.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-32.json (deflated 80%)
#   adding: ../outputs_distilbert/easy/solution-problem-779.json (deflated 68%)
#   adding: ../outputs_distilbert/easy/solution-problem-522.json (deflated 76%)
#   adding: ../outputs_distilbert/easy/solution-problem-741.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-412.json (deflated 63%)
#   adding: ../outputs_distilbert/easy/solution-problem-366.json (deflated 78%)
#   adding: ../outputs_distilbert/easy/solution-problem-83.json (deflated 80%)
#   adding: ../outputs_distilbert/easy/solution-problem-60.json (deflated 66%)
#   adding: ../outputs_distilbert/easy/solution-problem-897.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-784.json (deflated 80%)
#   adding: ../outputs_distilbert/easy/solution-problem-757.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-508.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-547.json (deflated 70%)
#   adding: ../outputs_distilbert/easy/solution-problem-163.json (deflated 64%)
#   adding: ../outputs_distilbert/easy/solution-problem-101.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-86.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-38.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-259.json (deflated 65%)
#   adding: ../outputs_distilbert/easy/solution-problem-319.json (deflated 82%)
#   adding: ../outputs_distilbert/easy/solution-problem-137.json (deflated 83%)
#   adding: ../outputs_distilbert/easy/solution-problem-632.json (deflated 71%)
#   adding: ../outputs_distilbert/easy/solution-problem-866.json (deflated 41%)
#   adding: ../outputs_distilbert/easy/solution-problem-566.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-893.json (deflated 76%)
#   adding: ../outputs_distilbert/easy/solution-problem-336.json (deflated 71%)
#   adding: ../outputs_distilbert/easy/solution-problem-812.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-258.json (deflated 81%)
#   adding: ../outputs_distilbert/easy/solution-problem-116.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-346.json (deflated 78%)
#   adding: ../outputs_distilbert/easy/solution-problem-317.json (deflated 80%)
#   adding: ../outputs_distilbert/easy/solution-problem-686.json (deflated 65%)
#   adding: ../outputs_distilbert/easy/solution-problem-475.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-230.json (deflated 76%)
#   adding: ../outputs_distilbert/easy/solution-problem-782.json (deflated 83%)
#   adding: ../outputs_distilbert/easy/solution-problem-130.json (deflated 68%)
#   adding: ../outputs_distilbert/easy/solution-problem-145.json (deflated 79%)
#   adding: ../outputs_distilbert/easy/solution-problem-400.json (deflated 60%)
#   adding: ../outputs_distilbert/easy/solution-problem-500.json (deflated 82%)
#   adding: ../outputs_distilbert/easy/solution-problem-343.json (deflated 64%)
#   adding: ../outputs_distilbert/easy/solution-problem-872.json (deflated 58%)
#   adding: ../outputs_distilbert/easy/solution-problem-184.json (deflated 71%)
#   adding: ../outputs_distilbert/easy/solution-problem-548.json (deflated 80%)
#   adding: ../outputs_distilbert/easy/solution-problem-823.json (deflated 69%)
#   adding: ../outputs_distilbert/easy/solution-problem-637.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-432.json (deflated 79%)
#   adding: ../outputs_distilbert/easy/solution-problem-427.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-94.json (deflated 79%)
#   adding: ../outputs_distilbert/easy/solution-problem-201.json (deflated 82%)
#   adding: ../outputs_distilbert/easy/solution-problem-800.json (deflated 72%)
#   adding: ../outputs_distilbert/easy/solution-problem-794.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-833.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-292.json (deflated 69%)
#   adding: ../outputs_distilbert/easy/solution-problem-426.json (deflated 64%)
#   adding: ../outputs_distilbert/easy/solution-problem-680.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-704.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-215.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-539.json (deflated 74%)
#   adding: ../outputs_distilbert/easy/solution-problem-462.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-448.json (deflated 70%)
#   adding: ../outputs_distilbert/easy/solution-problem-660.json (deflated 70%)
#   adding: ../outputs_distilbert/easy/solution-problem-204.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-305.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-376.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-78.json (deflated 65%)
#   adding: ../outputs_distilbert/easy/solution-problem-886.json (deflated 83%)
#   adding: ../outputs_distilbert/easy/solution-problem-651.json (deflated 81%)
#   adding: ../outputs_distilbert/easy/solution-problem-9.json (deflated 80%)
#   adding: ../outputs_distilbert/easy/solution-problem-26.json (deflated 79%)
#   adding: ../outputs_distilbert/easy/solution-problem-235.json (deflated 66%)
#   adding: ../outputs_distilbert/easy/solution-problem-437.json (deflated 81%)
#   adding: ../outputs_distilbert/easy/solution-problem-858.json (deflated 78%)
#   adding: ../outputs_distilbert/easy/solution-problem-829.json (deflated 74%)
#   adding: ../outputs_distilbert/easy/solution-problem-605.json (deflated 81%)
#   adding: ../outputs_distilbert/easy/solution-problem-483.json (deflated 69%)
#   adding: ../outputs_distilbert/easy/solution-problem-194.json (deflated 68%)
#   adding: ../outputs_distilbert/easy/solution-problem-643.json (deflated 66%)
#   adding: ../outputs_distilbert/easy/solution-problem-851.json (deflated 79%)
#   adding: ../outputs_distilbert/easy/solution-problem-883.json (deflated 67%)
#   adding: ../outputs_distilbert/easy/solution-problem-747.json (deflated 65%)
#   adding: ../outputs_distilbert/easy/solution-problem-571.json (deflated 79%)
#   adding: ../outputs_distilbert/easy/solution-problem-347.json (deflated 68%)
#   adding: ../outputs_distilbert/easy/solution-problem-664.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-832.json (deflated 69%)
#   adding: ../outputs_distilbert/easy/solution-problem-56.json (deflated 85%)
#   adding: ../outputs_distilbert/easy/solution-problem-67.json (deflated 78%)
#   adding: ../outputs_distilbert/easy/solution-problem-459.json (deflated 76%)
#   adding: ../outputs_distilbert/easy/solution-problem-700.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-283.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-157.json (deflated 83%)
#   adding: ../outputs_distilbert/easy/solution-problem-1.json (deflated 55%)
#   adding: ../outputs_distilbert/easy/solution-problem-154.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-513.json (deflated 74%)
#   adding: ../outputs_distilbert/easy/solution-problem-813.json (deflated 76%)
#   adding: ../outputs_distilbert/easy/solution-problem-484.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-620.json (deflated 79%)
#   adding: ../outputs_distilbert/easy/solution-problem-360.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-287.json (deflated 78%)
#   adding: ../outputs_distilbert/easy/solution-problem-49.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-238.json (deflated 96%)
#   adding: ../outputs_distilbert/easy/solution-problem-415.json (deflated 80%)
#   adding: ../outputs_distilbert/easy/solution-problem-578.json (deflated 74%)
#   adding: ../outputs_distilbert/easy/solution-problem-16.json (deflated 55%)
#   adding: ../outputs_distilbert/easy/solution-problem-340.json (deflated 71%)
#   adding: ../outputs_distilbert/easy/solution-problem-497.json (deflated 74%)
#   adding: ../outputs_distilbert/easy/solution-problem-40.json (deflated 72%)
#   adding: ../outputs_distilbert/easy/solution-problem-250.json (deflated 59%)
#   adding: ../outputs_distilbert/easy/solution-problem-545.json (deflated 71%)
#   adding: ../outputs_distilbert/easy/solution-problem-752.json (deflated 79%)
#   adding: ../outputs_distilbert/easy/solution-problem-778.json (deflated 78%)
#   adding: ../outputs_distilbert/easy/solution-problem-237.json (deflated 91%)
#   adding: ../outputs_distilbert/easy/solution-problem-793.json (deflated 72%)
#   adding: ../outputs_distilbert/easy/solution-problem-20.json (deflated 71%)
#   adding: ../outputs_distilbert/easy/solution-problem-623.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-523.json (deflated 70%)
#   adding: ../outputs_distilbert/easy/solution-problem-720.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-542.json (deflated 71%)
#   adding: ../outputs_distilbert/easy/solution-problem-310.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-766.json (deflated 70%)
#   adding: ../outputs_distilbert/easy/solution-problem-222.json (deflated 79%)
#   adding: ../outputs_distilbert/easy/solution-problem-551.json (deflated 55%)
#   adding: ../outputs_distilbert/easy/solution-problem-397.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-209.json (deflated 71%)
#   adding: ../outputs_distilbert/easy/solution-problem-606.json (deflated 81%)
#   adding: ../outputs_distilbert/easy/solution-problem-321.json (deflated 74%)
#   adding: ../outputs_distilbert/easy/solution-problem-555.json (deflated 61%)
#   adding: ../outputs_distilbert/easy/solution-problem-767.json (deflated 76%)
#   adding: ../outputs_distilbert/easy/solution-problem-649.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-504.json (deflated 79%)
#   adding: ../outputs_distilbert/easy/solution-problem-357.json (deflated 78%)
#   adding: ../outputs_distilbert/easy/solution-problem-853.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-672.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-236.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-451.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-815.json (deflated 68%)
#   adding: ../outputs_distilbert/easy/solution-problem-805.json (deflated 70%)
#   adding: ../outputs_distilbert/easy/solution-problem-179.json (deflated 52%)
#   adding: ../outputs_distilbert/easy/solution-problem-89.json (deflated 82%)
#   adding: ../outputs_distilbert/easy/solution-problem-299.json (deflated 79%)
#   adding: ../outputs_distilbert/easy/solution-problem-279.json (deflated 81%)
#   adding: ../outputs_distilbert/easy/solution-problem-266.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-211.json (deflated 84%)
#   adding: ../outputs_distilbert/easy/solution-problem-374.json (deflated 80%)
#   adding: ../outputs_distilbert/easy/solution-problem-358.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-441.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-100.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-131.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-880.json (deflated 62%)
#   adding: ../outputs_distilbert/easy/solution-problem-382.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-535.json (deflated 74%)
#   adding: ../outputs_distilbert/easy/solution-problem-381.json (deflated 70%)
#   adding: ../outputs_distilbert/easy/solution-problem-751.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-62.json (deflated 78%)
#   adding: ../outputs_distilbert/easy/solution-problem-572.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-521.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-196.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-661.json (deflated 64%)
#   adding: ../outputs_distilbert/easy/solution-problem-227.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-803.json (deflated 71%)
#   adding: ../outputs_distilbert/easy/solution-problem-80.json (deflated 77%)
#   adding: ../outputs_distilbert/easy/solution-problem-659.json (deflated 76%)
#   adding: ../outputs_distilbert/easy/solution-problem-260.json (deflated 69%)
#   adding: ../outputs_distilbert/easy/solution-problem-891.json (deflated 66%)
#   adding: ../outputs_distilbert/easy/solution-problem-879.json (deflated 70%)
#   adding: ../outputs_distilbert/easy/solution-problem-841.json (deflated 68%)
#   adding: ../outputs_distilbert/easy/solution-problem-619.json (deflated 78%)
#   adding: ../outputs_distilbert/easy/solution-problem-728.json (deflated 68%)
#   adding: ../outputs_distilbert/easy/solution-problem-856.json (deflated 74%)
#   adding: ../outputs_distilbert/easy/solution-problem-160.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-810.json (deflated 74%)
#   adding: ../outputs_distilbert/easy/solution-problem-146.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-889.json (deflated 66%)
#   adding: ../outputs_distilbert/easy/solution-problem-822.json (deflated 74%)
#   adding: ../outputs_distilbert/easy/solution-problem-799.json (deflated 76%)
#   adding: ../outputs_distilbert/easy/solution-problem-712.json (deflated 79%)
#   adding: ../outputs_distilbert/easy/solution-problem-370.json (deflated 82%)
#   adding: ../outputs_distilbert/easy/solution-problem-33.json (deflated 73%)
#   adding: ../outputs_distilbert/easy/solution-problem-416.json (deflated 69%)
#   adding: ../outputs_distilbert/easy/solution-problem-490.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-417.json (deflated 60%)
#   adding: ../outputs_distilbert/easy/solution-problem-326.json (deflated 69%)
#   adding: ../outputs_distilbert/easy/solution-problem-640.json (deflated 69%)
#   adding: ../outputs_distilbert/easy/solution-problem-371.json (deflated 75%)
#   adding: ../outputs_distilbert/easy/solution-problem-684.json (deflated 80%)
#   adding: ../outputs_distilbert/easy/solution-problem-136.json (deflated 80%)
# ...
#   adding: ../outputs_distilbert/hard/solution-problem-122.json (deflated 71%)
#   adding: ../outputs_distilbert/hard/solution-problem-155.json (deflated 82%)
#   adding: ../outputs_distilbert/hard/solution-problem-438.json (deflated 73%)
#   adding: ../outputs_distilbert/hard/solution-problem-777.json (deflated 77%)
#   adding: ../outputs_distilbert/hard/solution-problem-306.json (deflated 64%)
#   adding: ../outputs_distilbert/hard/solution-problem-587.json (deflated 83%)
#   adding: ../outputs_distilbert/hard/solution-problem-302.json (deflated 70%)
#   adding: ../outputs_distilbert/hard/solution-problem-613.json (deflated 80%)
#   adding: ../outputs_distilbert/hard/solution-problem-142.json (deflated 79%)
#   adding: ../outputs_distilbert/hard/solution-problem-304.json (deflated 73%)
#   adding: ../outputs_distilbert/hard/solution-problem-636.json (deflated 77%)
#   adding: ../outputs_distilbert/hard/solution-problem-7.json (deflated 79%)
#   adding: ../outputs_distilbert/hard/solution-problem-512.json (deflated 65%)
#   adding: ../outputs_distilbert/hard/solution-problem-838.json (deflated 66%)
#   adding: ../outputs_distilbert/hard/solution-problem-248.json (deflated 60%)
#   adding: ../outputs_distilbert/hard/solution-problem-174.json (deflated 87%)
#   adding: ../outputs_distilbert/hard/solution-problem-365.json (deflated 82%)
#   adding: ../outputs_distilbert/hard/solution-problem-393.json (deflated 64%)
#   adding: ../outputs_distilbert/hard/solution-problem-308.json (deflated 80%)
#   adding: ../outputs_distilbert/hard/solution-problem-556.json (deflated 63%)
#   adding: ../outputs_distilbert/hard/solution-problem-167.json (deflated 75%)
#   adding: ../outputs_distilbert/hard/solution-problem-480.json (deflated 52%)
#   adding: ../outputs_distilbert/hard/solution-problem-635.json (deflated 77%)
#   adding: ../outputs_distilbert/hard/solution-problem-228.json (deflated 90%)
#   adding: ../outputs_distilbert/hard/solution-problem-10.json (deflated 77%)
#   adding: ../outputs_distilbert/hard/solution-problem-582.json (deflated 89%)
#   adding: ../outputs_distilbert/hard/solution-problem-732.json (deflated 85%)
#   adding: ../outputs_distilbert/hard/solution-problem-275.json (deflated 80%)
#   adding: ../outputs_distilbert/hard/solution-problem-285.json (deflated 79%)
#   adding: ../outputs_distilbert/hard/solution-problem-447.json (deflated 61%)
#   adding: ../outputs_distilbert/hard/solution-problem-711.json (deflated 75%)
#   adding: ../outputs_distilbert/hard/solution-problem-528.json (deflated 73%)
#   adding: ../outputs_distilbert/hard/solution-problem-219.json (deflated 70%)
#   adding: ../outputs_distilbert/hard/solution-problem-749.json (deflated 90%)
#   adding: ../outputs_distilbert/hard/solution-problem-303.json (deflated 87%)
#   adding: ../outputs_distilbert/hard/solution-problem-609.json (deflated 71%)
#   adding: ../outputs_distilbert/hard/solution-problem-192.json (deflated 71%)
#   adding: ../outputs_distilbert/hard/solution-problem-594.json (deflated 77%)
#   adding: ../outputs_distilbert/hard/solution-problem-387.json (deflated 89%)
#   adding: ../outputs_distilbert/hard/solution-problem-843.json (deflated 77%)
#   adding: ../outputs_distilbert/hard/solution-problem-569.json (deflated 79%)
#   adding: ../outputs_distilbert/hard/solution-problem-149.json (deflated 83%)
#   adding: ../outputs_distilbert/hard/solution-problem-801.json (deflated 91%)
#   adding: ../outputs_distilbert/hard/solution-problem-486.json (deflated 77%)
#   adding: ../outputs_distilbert/hard/solution-problem-568.json (deflated 77%)
#   adding: ../outputs_distilbert/hard/solution-problem-769.json (deflated 75%)
#   adding: ../outputs_distilbert/hard/solution-problem-628.json (deflated 80%)
#   adding: ../outputs_distilbert/hard/solution-problem-564.json (deflated 83%)
#   adding: ../outputs_distilbert/hard/solution-problem-189.json (deflated 77%)
#   adding: ../outputs_distilbert/hard/solution-problem-152.json (deflated 70%)
#   adding: ../outputs_distilbert/hard/solution-problem-378.json (deflated 88%)
#   adding: ../outputs_distilbert/hard/solution-problem-855.json (deflated 79%)
#   adding: ../outputs_distilbert/hard/solution-problem-64.json (deflated 75%)
#   adding: ../outputs_distilbert/hard/solution-problem-738.json (deflated 68%)
#   adding: ../outputs_distilbert/hard/solution-problem-22.json (deflated 78%)
#   adding: ../outputs_distilbert/hard/solution-problem-226.json (deflated 84%)
#   adding: ../outputs_distilbert/hard/solution-problem-434.json (deflated 83%)
#   adding: ../outputs_distilbert/hard/solution-problem-123.json (deflated 85%)
#   adding: ../outputs_distilbert/hard/solution-problem-45.json (deflated 74%)
#   adding: ../outputs_distilbert/hard/solution-problem-586.json (deflated 75%)
#   adding: ../outputs_distilbert/hard/solution-problem-143.json (deflated 73%)
#   adding: ../outputs_distilbert/hard/solution-problem-313.json (deflated 73%)
#   adding: ../outputs_distilbert/hard/solution-problem-410.json (deflated 83%)
#   adding: ../outputs_distilbert/hard/solution-problem-774.json (deflated 85%)
#   adding: ../outputs_distilbert/hard/solution-problem-473.json (deflated 75%)
#   adding: ../outputs_distilbert/hard/solution-problem-97.json (deflated 80%)
#   adding: ../outputs_distilbert/hard/solution-problem-826.json (deflated 75%)
#   adding: ../outputs_distilbert/hard/solution-problem-618.json (deflated 81%)
#   adding: ../outputs_distilbert/hard/solution-problem-429.json (deflated 85%)
#   adding: ../outputs_distilbert/hard/solution-problem-482.json (deflated 84%)
#   adding: ../outputs_distilbert/hard/solution-problem-240.json (deflated 63%)
#   adding: ../outputs_distilbert/hard/solution-problem-327.json (deflated 68%)
#   adding: ../outputs_distilbert/hard/solution-problem-18.json (deflated 77%)
#   adding: ../outputs_distilbert/hard/solution-problem-377.json (deflated 82%)
#   adding: ../outputs_distilbert/hard/solution-problem-685.json (deflated 80%)
#   adding: ../outputs_distilbert/hard/solution-problem-524.json (deflated 81%)
#   adding: ../outputs_distilbert/hard/solution-problem-724.json (deflated 84%)
#   adding: ../outputs_distilbert/hard/solution-problem-762.json (deflated 77%)
#   adding: ../outputs_distilbert/hard/solution-problem-601.json (deflated 78%)
#   adding: ../outputs_distilbert/hard/solution-problem-573.json (deflated 86%)
#   adding: ../outputs_distilbert/hard/solution-problem-252.json (deflated 85%)
#   adding: ../outputs_distilbert/hard/solution-problem-554.json (deflated 79%)
#   adding: ../outputs_distilbert/hard/solution-problem-795.json (deflated 79%)
#   adding: ../outputs_distilbert/hard/solution-problem-182.json (deflated 80%)
#   adding: ../outputs_distilbert/hard/solution-problem-288.json (deflated 67%)
#   adding: ../outputs_distilbert/hard/solution-problem-559.json (deflated 78%)
#   adding: ../outputs_distilbert/hard/solution-problem-48.json (deflated 89%)
#   adding: ../outputs_distilbert/hard/solution-problem-54.json (deflated 73%)
#   adding: ../outputs_distilbert/hard/solution-problem-748.json (deflated 73%)
#   adding: ../outputs_distilbert/hard/solution-problem-105.json (deflated 68%)
#   adding: ../outputs_distilbert/hard/solution-problem-428.json (deflated 68%)
#   adding: ../outputs_distilbert/hard/solution-problem-498.json (deflated 80%)
#   adding: ../outputs_distilbert/hard/solution-problem-335.json (deflated 71%)
#   adding: ../outputs_distilbert/hard/solution-problem-693.json (deflated 78%)
#   adding: ../outputs_distilbert/hard/solution-problem-404.json (deflated 75%)
#   adding: ../outputs_distilbert/hard/solution-problem-436.json (deflated 84%)
#   adding: ../outputs_distilbert/hard/solution-problem-318.json (deflated 62%)
#   adding: ../outputs_distilbert/hard/solution-problem-361.json (deflated 80%)
#   adding: ../outputs_distilbert/hard/solution-problem-99.json (deflated 80%)
#   adding: ../outputs_distilbert/hard/solution-problem-413.json (deflated 75%)
#   adding: ../outputs_distilbert/hard/solution-problem-890.json (deflated 86%)
#   adding: ../outputs_distilbert/hard/solution-problem-51.json (deflated 75%)
#   adding: ../outputs_distilbert/hard/solution-problem-455.json (deflated 68%)
#   adding: ../outputs_distilbert/hard/solution-problem-239.json (deflated 71%)
#   adding: ../outputs_distilbert/hard/solution-problem-177.json (deflated 77%)
#   adding: ../outputs_distilbert/hard/solution-problem-758.json (deflated 75%)
#   adding: ../outputs_distilbert/hard/solution-problem-682.json (deflated 79%)
#   adding: ../outputs_distilbert/hard/solution-problem-247.json (deflated 75%)
#   adding: ../outputs_distilbert/hard/solution-problem-251.json (deflated 59%)
#   adding: ../outputs_distilbert/hard/solution-problem-339.json (deflated 72%)
#   adding: ../outputs_distilbert/hard/solution-problem-23.json (deflated 79%)
#   adding: ../outputs_distilbert/hard/solution-problem-478.json (deflated 79%)
#   adding: ../outputs_distilbert/hard/solution-problem-372.json (deflated 71%)
#   adding: ../outputs_distilbert/hard/solution-problem-537.json (deflated 79%)
#   adding: ../outputs_distilbert/hard/solution-problem-385.json (deflated 90%)
#   adding: ../outputs_distilbert/hard/solution-problem-63.json (deflated 79%)
#   adding: ../outputs_distilbert/hard/solution-problem-487.json (deflated 73%)
#   adding: ../outputs_distilbert/hard/solution-problem-881.json (deflated 79%)
#   adding: ../outputs_distilbert/hard/solution-problem-873.json (deflated 86%)
#   adding: ../outputs_distilbert/hard/solution-problem-648.json (deflated 81%)
#   adding: ../outputs_distilbert/hard/solution-problem-386.json (deflated 69%)
#   adding: ../outputs_distilbert/hard/solution-problem-713.json (deflated 77%)
#   adding: ../outputs_distilbert/hard/solution-problem-225.json (deflated 74%)
#   adding: ../outputs_distilbert/hard/solution-problem-565.json (deflated 83%)
#   adding: ../outputs_distilbert/hard/solution-problem-338.json (deflated 74%)
#   adding: ../outputs_distilbert/hard/solution-problem-185.json (deflated 59%)
#   adding: ../outputs_distilbert/hard/solution-problem-103.json (deflated 78%)
#   adding: ../outputs_distilbert/hard/solution-problem-789.json (deflated 80%)
#   adding: ../outputs_distilbert/hard/solution-problem-278.json (deflated 77%)
#   adding: ../outputs_distilbert/hard/solution-problem-307.json (deflated 80%)
#   adding: ../outputs_distilbert/hard/solution-problem-791.json (deflated 75%)
#   adding: ../outputs_distilbert/hard/solution-problem-593.json (deflated 77%)
#   adding: ../outputs_distilbert/hard/solution-problem-622.json (deflated 78%)
#   adding: ../outputs_distilbert/hard/solution-problem-895.json (deflated 78%)
#   adding: ../outputs_distilbert/hard/solution-problem-468.json (deflated 73%)
#   adding: ../outputs_distilbert/hard/solution-problem-29.json (deflated 60%)
#   adding: ../outputs_distilbert/hard/solution-problem-13.json (deflated 70%)
#   adding: ../outputs_distilbert/hard/solution-problem-21.json (deflated 83%)
#   adding: ../outputs_distilbert/hard/solution-problem-301.json (deflated 80%)
#   adding: ../outputs_distilbert/hard/solution-problem-65.json (deflated 81%)
#   adding: ../outputs_distilbert/hard/solution-problem-256.json (deflated 70%)
#   adding: ../outputs_distilbert/hard/solution-problem-706.json (deflated 79%)
#   adding: ../outputs_distilbert/hard/solution-problem-804.json (deflated 79%)
#   adding: ../outputs_distilbert/hard/solution-problem-852.json (deflated 57%)
#   adding: ../outputs_distilbert/hard/solution-problem-188.json (deflated 78%)
#   adding: ../outputs_distilbert/hard/solution-problem-585.json (deflated 73%)
#   adding: ../outputs_distilbert/hard/solution-problem-212.json (deflated 73%)
#   adding: ../outputs_distilbert/hard/solution-problem-229.json (deflated 64%)
#   adding: ../outputs_distilbert/hard/solution-problem-867.json (deflated 75%)
#   adding: ../outputs_distilbert/hard/solution-problem-868.json (deflated 79%)
#   adding: ../outputs_distilbert/hard/solution-problem-583.json (deflated 75%)
#   adding: ../outputs_distilbert/hard/solution-problem-440.json (deflated 70%)
#   adding: ../outputs_distilbert/hard/solution-problem-379.json (deflated 64%)
#   adding: ../outputs_distilbert/hard/solution-problem-506.json (deflated 67%)
#   adding: ../outputs_distilbert/hard/solution-problem-216.json (deflated 80%)
#   adding: ../outputs_distilbert/hard/solution-problem-364.json (deflated 75%)
#   adding: ../outputs_distilbert/hard/solution-problem-272.json (deflated 78%)
#   adding: ../outputs_distilbert/hard/solution-problem-121.json (deflated 77%)
#   adding: ../outputs_distilbert/hard/solution-problem-294.json (deflated 68%)
#   adding: ../outputs_distilbert/hard/solution-problem-91.json (deflated 85%)
#   adding: ../outputs_distilbert/hard/solution-problem-869.json (deflated 73%)
#   adding: ../outputs_distilbert/hard/solution-problem-296.json (deflated 77%)
#   adding: ../outputs_distilbert/hard/solution-problem-669.json (deflated 72%)
#   adding: ../outputs_distilbert/hard/solution-problem-342.json (deflated 75%)
#   adding: ../outputs_distilbert/hard/solution-problem-2.json (deflated 73%)
#   adding: ../outputs_distilbert/hard/solution-problem-271.json (deflated 71%)
#   adding: ../outputs_distilbert/hard/solution-problem-234.json (deflated 69%)
#   adding: ../outputs_distilbert/hard/solution-problem-110.json (deflated 66%)
#   adding: ../outputs_distilbert/hard/solution-problem-634.json (deflated 71%)
#   adding: ../outputs_distilbert/hard/solution-problem-667.json (deflated 82%)
#   adding: ../outputs_distilbert/hard/solution-problem-233.json (deflated 66%)
#   adding: ../outputs_distilbert/hard/solution-problem-217.json (deflated 73%)
#   adding: ../outputs_distilbert/hard/solution-problem-464.json (deflated 85%)
#   adding: ../outputs_distilbert/hard/solution-problem-608.json (deflated 91%)
#   adding: ../outputs_distilbert/hard/solution-problem-658.json (deflated 70%)
#   adding: ../outputs_distilbert/hard/solution-problem-210.json (deflated 77%)
#   adding: ../outputs_distilbert/hard/solution-problem-257.json (deflated 77%)
#   adding: ../outputs_distilbert/hard/solution-problem-25.json (deflated 81%)
#   adding: ../outputs_distilbert/hard/solution-problem-324.json (deflated 75%)
#   adding: ../outputs_distilbert/hard/solution-problem-750.json (deflated 66%)
#   adding: ../outputs_distilbert/hard/solution-problem-187.json (deflated 75%)
#   adding: ../outputs_distilbert/hard/solution-problem-290.json (deflated 79%)
#   adding: ../outputs_distilbert/hard/solution-problem-348.json (deflated 67%)
#   adding: ../outputs_distilbert/hard/solution-problem-656.json (deflated 75%)
#   adding: ../outputs_distilbert/hard/solution-problem-882.json (deflated 63%)
#   adding: ../outputs_distilbert/hard/solution-problem-375.json (deflated 59%)
#   adding: ../outputs_distilbert/hard/solution-problem-821.json (deflated 70%)
#   adding: ../outputs_distilbert/hard/solution-problem-50.json (deflated 73%)
#   adding: ../outputs_distilbert/hard/solution-problem-514.json (deflated 79%)
#   adding: ../outputs_distilbert/hard/solution-problem-423.json (deflated 75%)
#   adding: ../outputs_distilbert/hard/solution-problem-760.json (deflated 80%)
#   adding: ../outputs_distilbert/hard/solution-problem-878.json (deflated 81%)
#   adding: ../outputs_distilbert/hard/solution-problem-350.json (deflated 79%)
#   adding: ../outputs_distilbert/hard/solution-problem-269.json (deflated 73%)
#   adding: ../outputs_distilbert/hard/solution-problem-675.json (deflated 79%)
#   adding: ../outputs_distilbert/hard/solution-problem-727.json (deflated 83%)
#   adding: ../outputs_distilbert/hard/solution-problem-666.json (deflated 85%)
#   adding: ../outputs_distilbert/hard/solution-problem-135.json (deflated 84%)
#   adding: ../outputs_distilbert/hard/solution-problem-424.json (deflated 87%)
#   adding: ../outputs_distilbert/hard/solution-problem-816.json (deflated 77%)
#   adding: ../outputs_distilbert/hard/solution-problem-744.json (deflated 75%)
#   adding: ../outputs_distilbert/hard/solution-problem-679.json (deflated 71%)
#   adding: ../outputs_distilbert/hard/solution-problem-186.json (deflated 82%)
#   adding: ../outputs_distilbert/hard/solution-problem-515.json (deflated 69%)
#   adding: ../outputs_distilbert/hard/solution-problem-550.json (deflated 82%)

# %%
files.download("/content/outputs_distilbert.zip")

# %%
model.save_pretrained(model_dir)
tokenizer.save_pretrained(model_dir)
# Out:
# ('../models/tokenizer_config.json',
#  '../models/special_tokens_map.json',
#  '../models/vocab.txt',
#  '../models/added_tokens.json')

# %%
# !zip -r /content/distilbert_model.zip ../models/
# Out:
# updating: ../models/ (stored 0%)
# updating: ../models/distilbert_model.pth (deflated 8%)
#   adding: ../models/tokenizer_config.json (deflated 75%)
#   adding: ../models/model.safetensors (deflated 8%)
#   adding: ../models/special_tokens_map.json (deflated 42%)
#   adding: ../models/config.json (deflated 45%)
#   adding: ../models/vocab.txt (deflated 53%)

# %%
files.download("/content/distilbert_model.zip")
