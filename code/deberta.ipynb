# %%
from getpass import getpass

# Prompt for GitHub username and PAT
username = 'sarim13'
token = getpass('Enter your GitHub personal access token: ')  # Input the token you generated

# !git clone https://{username}:{token}@github.com/AliMuhammadAsad/PAN2025-MultiAuthor-LLMs-Project.git
# Out:
# Enter your GitHub personal access token: ··········
# Cloning into 'PAN2025-MultiAuthor-LLMs-Project'...
# remote: Enumerating objects: 24859, done.
# remote: Counting objects: 100% (2438/2438), done.
# remote: Compressing objects: 100% (231/231), done.
# remote: Total 24859 (delta 2373), reused 2261 (delta 2200), pack-reused 22421 (from 1)
# Receiving objects: 100% (24859/24859), 27.52 MiB | 21.66 MiB/s, done.
# Resolving deltas: 100% (4445/4445), done.
# Updating files: 100% (118848/118848), done.

# %%
import os
import json
import numpy as np
import torch
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load dataset function remains the same
def load_dataset(base_path):
    levels = ['easy', 'medium', 'hard']
    splits = ['train', 'validation']
    dataset = {}

    for level in levels:
        dataset[level] = {}
        for split in splits:
            split_path = os.path.join(base_path, level, split)
            documents = []

            for filename in sorted(os.listdir(split_path)):
                if filename.startswith('problem-') and filename.endswith('.txt'):
                    problem_id = filename.split('.')[0]
                    txt_path = os.path.join(split_path, filename)
                    json_path = os.path.join(split_path, f'truth-{problem_id}.json')

                    with open(txt_path, 'r', encoding='utf-8') as f:
                        sentences = [line.strip() for line in f.readlines() if line.strip()]

                    with open(json_path, 'r', encoding='utf-8') as f:
                        truth = json.load(f)
                        changes = truth['changes']

                    documents.append((sentences, changes, problem_id))

            dataset[level][split] = documents

    return dataset

# Custom dataset class for DeBERTa
tokenizer = AutoTokenizer.from_pretrained("microsoft/deberta-v3-small")

class SentencePairDataset(Dataset):
    def __init__(self, documents):
        self.sentences = []
        self.labels = []
        self.problem_ids = []
        self.offsets = []  # To track the global position of sentence pairs
        offset = 0

        for sentences, changes, problem_id in documents:
            for i in range(len(changes)):
                # Create sentence pair (i-th and (i+1)-th sentences)
                self.sentences.append((sentences[i], sentences[i + 1]))
                self.labels.append(changes[i])
                self.problem_ids.append((problem_id, i))
                self.offsets.append(offset + i)  # Append global offset (starting at 0)

            # Update the offset after processing the document
            offset += len(changes)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        text_pair = self.sentences[idx]
        inputs = tokenizer(text_pair[0], text_pair[1], truncation=True, padding='max_length', max_length=128, return_tensors='pt')

        return {
            "input_ids": inputs["input_ids"].squeeze(),
            "attention_mask": inputs["attention_mask"].squeeze(),
            "labels": torch.tensor(self.labels[idx], dtype=torch.long),
            "problem_id": self.problem_ids[idx],  # Include the problem_id
            "offset": torch.tensor(self.offsets[idx], dtype=torch.long)  # Include the offset
        }


# Function to plot confusion matrix
def plot_confusion_matrix(y_true, y_pred, title):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
                xticklabels=['No Change (0)', 'Change (1)'],
                yticklabels=['No Change (0)', 'Change (1)'])
    plt.title(title)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()
    return cm

def save_predictions_to_json(predictions, problem_ids_with_offsets, output_base_path, level, split):
    """
    Save predictions as solution-problem-X.json files for each problem.
    """
    output_dir = os.path.join(output_base_path, level)
    os.makedirs(output_dir, exist_ok=True)

    # Group predictions by problem_id
    pred_dict = {}
    for pred, (problem_id, idx, offset) in zip(predictions, problem_ids_with_offsets):
        if problem_id not in pred_dict:
            pred_dict[problem_id] = []
        # Convert NumPy int64 to Python int
        pred_dict[problem_id].append(int(pred))

    # Write each problem's predictions to a JSON file
    for problem_id, changes in pred_dict.items():
        solution = {"changes": changes}
        output_path = os.path.join(output_dir, f'solution-{problem_id}.json')
        with open(output_path, 'w', encoding='utf-8') as f:
            json.dump(solution, f, indent=4)
        print(f"Saved: {output_path}")

# Training and evaluation function
def train_and_evaluate_deberta(train_dataset, val_dataset, level, output_base_path):
    model = AutoModelForSequenceClassification.from_pretrained("microsoft/deberta-v3-base", num_labels=2)
    model.to(device)

    training_args = TrainingArguments(
        output_dir=f"./results_{level}",
        evaluation_strategy="epoch",
        save_strategy="epoch",
        logging_dir=f"./logs_{level}",
        per_device_train_batch_size=12,
        per_device_eval_batch_size=12,
        num_train_epochs=1,
        weight_decay=0.01,
        load_best_model_at_end=True,
        fp16=True,
        metric_for_best_model="f1",
    )

    def compute_metrics(eval_pred):
        logits, labels = eval_pred
        preds = np.argmax(logits, axis=1)
        return {
            "accuracy": accuracy_score(labels, preds),
            "f1": f1_score(labels, preds)
        }

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=val_dataset,
        compute_metrics=compute_metrics,
    )

    trainer.train()
    results = trainer.evaluate()
    predictions = trainer.predict(val_dataset)
    y_pred = np.argmax(predictions.predictions, axis=1)
    y_true = predictions.label_ids

    print(f"\n{level} Level Metrics:")
    print(f"Accuracy: {results['eval_accuracy']:.4f}, F1-Score: {results['eval_f1']:.4f}")
    print("Classification Report:")
    print(classification_report(y_true, y_pred, target_names=['No Change (0)', 'Change (1)']))
    val_problem_ids_with_offsets = [(problem_id, idx, offset)
                            for idx, (problem_id, offset) in enumerate(zip(val_dataset.problem_ids, val_dataset.offsets))]
    save_predictions_to_json(y_pred, val_problem_ids_with_offsets, output_base_path, level, 'validation')

    cm = plot_confusion_matrix(y_true, y_pred, f'Confusion Matrix - {level} Level')
    return model, y_pred, y_true, cm

# Load dataset and train model
dataset_dir = "PAN2025-MultiAuthor-LLMs-Project/dataset"
print("Loading dataset...")
dataset = load_dataset(dataset_dir)
output_path = "../outputs_deberta"

all_val_y = []
all_val_pred = []
all_cm = None

for level in ["easy", "medium", "hard"]:
    print(f"Processing {level} level...")
    train_docs = dataset[level]['train']
    val_docs = dataset[level]['validation']

    train_dataset = SentencePairDataset(train_docs)
    val_dataset = SentencePairDataset(val_docs)

    model, val_pred, val_y, cm = train_and_evaluate_deberta(train_dataset, val_dataset, level, output_path)

    all_val_y.extend(val_y)
    all_val_pred.extend(val_pred)
    if all_cm is None:
        all_cm = cm
    else:
        all_cm += cm

print("\nCombined Metrics Across All Levels:")
print("Classification Report:")
print(classification_report(all_val_y, all_val_pred, target_names=['No Change (0)', 'Change (1)']))
plot_confusion_matrix(all_val_y, all_val_pred, 'Combined Confusion Matrix - All Levels')

# Save model
model_dir = "../models"
os.makedirs(model_dir, exist_ok=True)
model.save_pretrained(model_dir)
tokenizer.save_pretrained(model_dir)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/578 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/transformers/convert_slow_tokenizer.py:561: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# Loading dataset...
# Processing easy level...
# config.json:   0%|          | 0.00/579 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/371M [00:00<?, ?B/s]
# Some weights of DebertaV2ForSequenceClassification were not initialized from the model checkpoint at microsoft/deberta-v3-base and are newly initialized: ['classifier.bias', 'classifier.weight', 'pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# model.safetensors:   0%|          | 0.00/371M [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: st07112 (st07112-habib-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/content/wandb/run-20250327_003225-65cagsph</code>
# Syncing run <strong><a href='https://wandb.ai/st07112-habib-university/huggingface/runs/65cagsph' target="_blank">./results_easy</a></strong> to <a href='https://wandb.ai/st07112-habib-university/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/st07112-habib-university/huggingface' target="_blank">https://wandb.ai/st07112-habib-university/huggingface</a>
#  View run at <a href='https://wandb.ai/st07112-habib-university/huggingface/runs/65cagsph' target="_blank">https://wandb.ai/st07112-habib-university/huggingface/runs/65cagsph</a>
#     <div>
#
#       <progress value='4034' max='4034' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4034/4034 14:11, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.204300</td>
#       <td>0.208601</td>
#       <td>0.932761</td>
#       <td>0.835991</td>
#     </tr>
#   </tbody>
# </table><p>
# Streaming output truncated to the last 5000 lines.
# Saved: ../outputs_deberta/easy/solution-('problem-512', 12).json
# Saved: ../outputs_deberta/easy/solution-('problem-512', 13).json
# Saved: ../outputs_deberta/easy/solution-('problem-512', 14).json
# Saved: ../outputs_deberta/easy/solution-('problem-512', 15).json
# Saved: ../outputs_deberta/easy/solution-('problem-513', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-513', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-513', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-513', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-513', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-513', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-513', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-513', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-513', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-513', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-513', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-514', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-514', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-514', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-514', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-514', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-514', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-514', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-514', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-514', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-514', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-514', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-514', 11).json
# Saved: ../outputs_deberta/easy/solution-('problem-515', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-515', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-515', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-515', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-515', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-515', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-515', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-515', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-515', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-515', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-515', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-515', 11).json
# Saved: ../outputs_deberta/easy/solution-('problem-515', 12).json
# Saved: ../outputs_deberta/easy/solution-('problem-516', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-516', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-516', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-516', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-516', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-517', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-517', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-517', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-517', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-517', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-517', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-517', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-517', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-517', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-517', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-518', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-518', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-518', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-518', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-518', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-518', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-518', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-518', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-518', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-518', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-518', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-518', 11).json
# Saved: ../outputs_deberta/easy/solution-('problem-518', 12).json
# Saved: ../outputs_deberta/easy/solution-('problem-519', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-519', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-519', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-519', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-519', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-519', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-519', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-519', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-519', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-519', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-519', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-519', 11).json
# Saved: ../outputs_deberta/easy/solution-('problem-519', 12).json
# Saved: ../outputs_deberta/easy/solution-('problem-519', 13).json
# Saved: ../outputs_deberta/easy/solution-('problem-52', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-52', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-52', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-52', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-52', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-52', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-52', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-520', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-520', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-520', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-520', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-520', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-520', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-520', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-520', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-520', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-520', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-520', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-520', 11).json
# Saved: ../outputs_deberta/easy/solution-('problem-520', 12).json
# Saved: ../outputs_deberta/easy/solution-('problem-520', 13).json
# Saved: ../outputs_deberta/easy/solution-('problem-520', 14).json
# Saved: ../outputs_deberta/easy/solution-('problem-520', 15).json
# Saved: ../outputs_deberta/easy/solution-('problem-521', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-521', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-521', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-521', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-521', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-521', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-521', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-521', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-521', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-521', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-522', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-522', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-522', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-522', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-522', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-522', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-522', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-522', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-522', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-522', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-522', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-522', 11).json
# Saved: ../outputs_deberta/easy/solution-('problem-523', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-523', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-523', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-523', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-523', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-523', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-523', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-523', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-524', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-524', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-524', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-524', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-524', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-524', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-524', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-524', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-524', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-524', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-524', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-524', 11).json
# Saved: ../outputs_deberta/easy/solution-('problem-525', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-525', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-525', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-525', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-525', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-525', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-525', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-525', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-525', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-525', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-525', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-526', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-526', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-526', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-526', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-526', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-526', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-526', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-526', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-526', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-526', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-527', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-527', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-527', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-527', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-527', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-527', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-527', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-528', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-528', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-528', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-528', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-528', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-529', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-529', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-529', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-529', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-529', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-529', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-529', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-529', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-529', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-529', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-529', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-529', 11).json
# Saved: ../outputs_deberta/easy/solution-('problem-529', 12).json
# Saved: ../outputs_deberta/easy/solution-('problem-529', 13).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 11).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 12).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 13).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 14).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 15).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 16).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 17).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 18).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 19).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 20).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 21).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 22).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 23).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 24).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 25).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 26).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 27).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 28).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 29).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 30).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 31).json
# Saved: ../outputs_deberta/easy/solution-('problem-53', 32).json
# Saved: ../outputs_deberta/easy/solution-('problem-530', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-530', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-530', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-530', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-530', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-530', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-530', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-530', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-530', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-530', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-530', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-530', 11).json
# Saved: ../outputs_deberta/easy/solution-('problem-530', 12).json
# Saved: ../outputs_deberta/easy/solution-('problem-530', 13).json
# Saved: ../outputs_deberta/easy/solution-('problem-530', 14).json
# Saved: ../outputs_deberta/easy/solution-('problem-531', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-531', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-531', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-531', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-531', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-531', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-531', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-531', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-531', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-531', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-531', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-531', 11).json
# Saved: ../outputs_deberta/easy/solution-('problem-531', 12).json
# Saved: ../outputs_deberta/easy/solution-('problem-532', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-532', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-532', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-532', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-532', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-532', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-532', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-532', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-532', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-532', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-532', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-532', 11).json
# Saved: ../outputs_deberta/easy/solution-('problem-532', 12).json
# Saved: ../outputs_deberta/easy/solution-('problem-533', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-533', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-533', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-533', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-533', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-533', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-533', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-533', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-533', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-534', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-534', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-534', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-534', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-534', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-534', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-534', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-534', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-534', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-534', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-534', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-534', 11).json
# Saved: ../outputs_deberta/easy/solution-('problem-534', 12).json
# Saved: ../outputs_deberta/easy/solution-('problem-534', 13).json
# Saved: ../outputs_deberta/easy/solution-('problem-534', 14).json
# Saved: ../outputs_deberta/easy/solution-('problem-534', 15).json
# Saved: ../outputs_deberta/easy/solution-('problem-535', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-535', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-535', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-535', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-535', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-535', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-535', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-535', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-535', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-535', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-535', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-536', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-536', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-536', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-536', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-536', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-536', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-536', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-536', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-536', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-537', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-537', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-537', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-537', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-537', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-537', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-537', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-537', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-537', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-537', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-537', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-537', 11).json
# Saved: ../outputs_deberta/easy/solution-('problem-537', 12).json
# Saved: ../outputs_deberta/easy/solution-('problem-537', 13).json
# Saved: ../outputs_deberta/easy/solution-('problem-538', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-538', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-538', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-538', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-538', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-538', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-538', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-538', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-538', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-538', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-538', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-538', 11).json
# Saved: ../outputs_deberta/easy/solution-('problem-538', 12).json
# Saved: ../outputs_deberta/easy/solution-('problem-538', 13).json
# Saved: ../outputs_deberta/easy/solution-('problem-538', 14).json
# Saved: ../outputs_deberta/easy/solution-('problem-539', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-539', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-539', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-539', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-539', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-539', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-539', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-539', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-539', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-539', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-539', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-54', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-54', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-54', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-54', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-54', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-54', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-54', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-54', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-54', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-54', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-54', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-54', 11).json
# Saved: ../outputs_deberta/easy/solution-('problem-54', 12).json
# Saved: ../outputs_deberta/easy/solution-('problem-54', 13).json
# Saved: ../outputs_deberta/easy/solution-('problem-54', 14).json
# Saved: ../outputs_deberta/easy/solution-('problem-54', 15).json
# Saved: ../outputs_deberta/easy/solution-('problem-54', 16).json
# Saved: ../outputs_deberta/easy/solution-('problem-54', 17).json
# Saved: ../outputs_deberta/easy/solution-('problem-540', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-540', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-540', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-540', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-540', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-540', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-540', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-540', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-540', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-541', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-541', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-541', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-541', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-541', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-541', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-541', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-541', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-541', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-542', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-542', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-542', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-542', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-542', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-542', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-542', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-542', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-542', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-543', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-543', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-543', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-543', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-543', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-543', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-543', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-543', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-543', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-543', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-544', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-544', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-544', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-544', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-544', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-544', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-544', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-544', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-544', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-544', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-544', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-545', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-545', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-545', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-545', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-545', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-545', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-545', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-545', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-545', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-545', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-546', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-546', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-546', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-546', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-546', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-546', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-546', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-546', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-546', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-546', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-546', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-546', 11).json
# Saved: ../outputs_deberta/easy/solution-('problem-546', 12).json
# Saved: ../outputs_deberta/easy/solution-('problem-546', 13).json
# Saved: ../outputs_deberta/easy/solution-('problem-546', 14).json
# Saved: ../outputs_deberta/easy/solution-('problem-546', 15).json
# Saved: ../outputs_deberta/easy/solution-('problem-546', 16).json
# Saved: ../outputs_deberta/easy/solution-('problem-546', 17).json
# Saved: ../outputs_deberta/easy/solution-('problem-547', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-547', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-547', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-547', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-547', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-547', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-547', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-547', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-548', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-548', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-548', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-548', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-548', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-548', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-548', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-548', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-548', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-548', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-548', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-548', 11).json
# Saved: ../outputs_deberta/easy/solution-('problem-548', 12).json
# Saved: ../outputs_deberta/easy/solution-('problem-548', 13).json
# Saved: ../outputs_deberta/easy/solution-('problem-548', 14).json
# Saved: ../outputs_deberta/easy/solution-('problem-548', 15).json
# Saved: ../outputs_deberta/easy/solution-('problem-548', 16).json
# Saved: ../outputs_deberta/easy/solution-('problem-549', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-549', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-549', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-549', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-549', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-55', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-55', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-55', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-55', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-55', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-55', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-55', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-55', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-55', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-55', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-55', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-55', 11).json
# Saved: ../outputs_deberta/easy/solution-('problem-55', 12).json
# Saved: ../outputs_deberta/easy/solution-('problem-55', 13).json
# Saved: ../outputs_deberta/easy/solution-('problem-550', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-550', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-550', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-550', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-550', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-550', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-550', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-550', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-550', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-550', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-550', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-550', 11).json
# Saved: ../outputs_deberta/easy/solution-('problem-550', 12).json
# Saved: ../outputs_deberta/easy/solution-('problem-551', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-551', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-551', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-551', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-551', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-552', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-552', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-552', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-552', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-552', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-552', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-552', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-552', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-552', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-552', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-552', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-552', 11).json
# Saved: ../outputs_deberta/easy/solution-('problem-553', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-553', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-553', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-553', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-553', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-553', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-553', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-553', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-553', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-553', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-553', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-553', 11).json
# Saved: ../outputs_deberta/easy/solution-('problem-553', 12).json
# Saved: ../outputs_deberta/easy/solution-('problem-554', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-554', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-554', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-554', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-554', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-554', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-554', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-554', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-554', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-554', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-554', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-554', 11).json
# Saved: ../outputs_deberta/easy/solution-('problem-554', 12).json
# Saved: ../outputs_deberta/easy/solution-('problem-555', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-555', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-555', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-555', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-555', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-556', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-556', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-556', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-556', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-556', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-556', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-556', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-556', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-556', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-556', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-556', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-556', 11).json
# Saved: ../outputs_deberta/easy/solution-('problem-556', 12).json
# Saved: ../outputs_deberta/easy/solution-('problem-556', 13).json
# Saved: ../outputs_deberta/easy/solution-('problem-556', 14).json
# Saved: ../outputs_deberta/easy/solution-('problem-557', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-557', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-557', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-557', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-557', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-557', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-557', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-558', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-558', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-558', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-558', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-558', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-558', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-558', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-558', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-558', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-558', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-558', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-559', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-559', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-559', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-559', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-559', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-559', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-559', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-559', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-559', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-559', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-559', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-559', 11).json
# Saved: ../outputs_deberta/easy/solution-('problem-56', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-56', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-56', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-56', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-56', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-56', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-56', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-56', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-56', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-56', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-56', 10).json
# Saved: ../outputs_deberta/easy/solution-('problem-56', 11).json
# Saved: ../outputs_deberta/easy/solution-('problem-56', 12).json
# Saved: ../outputs_deberta/easy/solution-('problem-56', 13).json
# Saved: ../outputs_deberta/easy/solution-('problem-56', 14).json
# Saved: ../outputs_deberta/easy/solution-('problem-56', 15).json
# Saved: ../outputs_deberta/easy/solution-('problem-56', 16).json
# Saved: ../outputs_deberta/easy/solution-('problem-56', 17).json
# Saved: ../outputs_deberta/easy/solution-('problem-56', 18).json
# Saved: ../outputs_deberta/easy/solution-('problem-56', 19).json
# Saved: ../outputs_deberta/easy/solution-('problem-560', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-560', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-560', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-560', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-560', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-560', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-560', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-560', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-560', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-561', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-561', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-561', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-561', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-561', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-561', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-561', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-561', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-561', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-561', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-562', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-562', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-562', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-562', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-563', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-563', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-563', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-563', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-563', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-563', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-563', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-563', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-563', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-563', 9).json
# Saved: ../outputs_deberta/easy/solution-('problem-564', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-564', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-564', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-564', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-564', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-564', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-564', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-564', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-564', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-565', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-565', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-565', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-565', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-565', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-565', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-565', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-565', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-566', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-566', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-566', 2).json
# Saved: ../outputs_deberta/easy/solution-('problem-566', 3).json
# Saved: ../outputs_deberta/easy/solution-('problem-566', 4).json
# Saved: ../outputs_deberta/easy/solution-('problem-566', 5).json
# Saved: ../outputs_deberta/easy/solution-('problem-566', 6).json
# Saved: ../outputs_deberta/easy/solution-('problem-566', 7).json
# Saved: ../outputs_deberta/easy/solution-('problem-566', 8).json
# Saved: ../outputs_deberta/easy/solution-('problem-567', 0).json
# Saved: ../outputs_deberta/easy/solution-('problem-567', 1).json
# Saved: ../outputs_deberta/easy/solution-('problem-567', 2).json
# ...
# Saved: ../outputs_deberta/hard/solution-('problem-894', 6).json
# Saved: ../outputs_deberta/hard/solution-('problem-894', 7).json
# Saved: ../outputs_deberta/hard/solution-('problem-894', 8).json
# Saved: ../outputs_deberta/hard/solution-('problem-894', 9).json
# Saved: ../outputs_deberta/hard/solution-('problem-894', 10).json
# Saved: ../outputs_deberta/hard/solution-('problem-894', 11).json
# Saved: ../outputs_deberta/hard/solution-('problem-894', 12).json
# Saved: ../outputs_deberta/hard/solution-('problem-894', 13).json
# Saved: ../outputs_deberta/hard/solution-('problem-895', 0).json
# Saved: ../outputs_deberta/hard/solution-('problem-895', 1).json
# Saved: ../outputs_deberta/hard/solution-('problem-895', 2).json
# Saved: ../outputs_deberta/hard/solution-('problem-895', 3).json
# Saved: ../outputs_deberta/hard/solution-('problem-895', 4).json
# Saved: ../outputs_deberta/hard/solution-('problem-895', 5).json
# Saved: ../outputs_deberta/hard/solution-('problem-895', 6).json
# Saved: ../outputs_deberta/hard/solution-('problem-895', 7).json
# Saved: ../outputs_deberta/hard/solution-('problem-895', 8).json
# Saved: ../outputs_deberta/hard/solution-('problem-895', 9).json
# Saved: ../outputs_deberta/hard/solution-('problem-895', 10).json
# Saved: ../outputs_deberta/hard/solution-('problem-895', 11).json
# Saved: ../outputs_deberta/hard/solution-('problem-895', 12).json
# Saved: ../outputs_deberta/hard/solution-('problem-895', 13).json
# Saved: ../outputs_deberta/hard/solution-('problem-896', 0).json
# Saved: ../outputs_deberta/hard/solution-('problem-896', 1).json
# Saved: ../outputs_deberta/hard/solution-('problem-896', 2).json
# Saved: ../outputs_deberta/hard/solution-('problem-896', 3).json
# Saved: ../outputs_deberta/hard/solution-('problem-896', 4).json
# Saved: ../outputs_deberta/hard/solution-('problem-896', 5).json
# Saved: ../outputs_deberta/hard/solution-('problem-896', 6).json
# Saved: ../outputs_deberta/hard/solution-('problem-897', 0).json
# Saved: ../outputs_deberta/hard/solution-('problem-897', 1).json
# Saved: ../outputs_deberta/hard/solution-('problem-897', 2).json
# Saved: ../outputs_deberta/hard/solution-('problem-897', 3).json
# Saved: ../outputs_deberta/hard/solution-('problem-897', 4).json
# Saved: ../outputs_deberta/hard/solution-('problem-897', 5).json
# Saved: ../outputs_deberta/hard/solution-('problem-897', 6).json
# Saved: ../outputs_deberta/hard/solution-('problem-897', 7).json
# Saved: ../outputs_deberta/hard/solution-('problem-897', 8).json
# Saved: ../outputs_deberta/hard/solution-('problem-897', 9).json
# Saved: ../outputs_deberta/hard/solution-('problem-897', 10).json
# Saved: ../outputs_deberta/hard/solution-('problem-897', 11).json
# Saved: ../outputs_deberta/hard/solution-('problem-897', 12).json
# Saved: ../outputs_deberta/hard/solution-('problem-897', 13).json
# Saved: ../outputs_deberta/hard/solution-('problem-897', 14).json
# Saved: ../outputs_deberta/hard/solution-('problem-897', 15).json
# Saved: ../outputs_deberta/hard/solution-('problem-898', 0).json
# Saved: ../outputs_deberta/hard/solution-('problem-898', 1).json
# Saved: ../outputs_deberta/hard/solution-('problem-898', 2).json
# Saved: ../outputs_deberta/hard/solution-('problem-898', 3).json
# Saved: ../outputs_deberta/hard/solution-('problem-898', 4).json
# Saved: ../outputs_deberta/hard/solution-('problem-898', 5).json
# Saved: ../outputs_deberta/hard/solution-('problem-898', 6).json
# Saved: ../outputs_deberta/hard/solution-('problem-898', 7).json
# Saved: ../outputs_deberta/hard/solution-('problem-898', 8).json
# Saved: ../outputs_deberta/hard/solution-('problem-899', 0).json
# Saved: ../outputs_deberta/hard/solution-('problem-899', 1).json
# Saved: ../outputs_deberta/hard/solution-('problem-899', 2).json
# Saved: ../outputs_deberta/hard/solution-('problem-899', 3).json
# Saved: ../outputs_deberta/hard/solution-('problem-899', 4).json
# Saved: ../outputs_deberta/hard/solution-('problem-899', 5).json
# Saved: ../outputs_deberta/hard/solution-('problem-899', 6).json
# Saved: ../outputs_deberta/hard/solution-('problem-899', 7).json
# Saved: ../outputs_deberta/hard/solution-('problem-899', 8).json
# Saved: ../outputs_deberta/hard/solution-('problem-899', 9).json
# Saved: ../outputs_deberta/hard/solution-('problem-899', 10).json
# Saved: ../outputs_deberta/hard/solution-('problem-899', 11).json
# Saved: ../outputs_deberta/hard/solution-('problem-899', 12).json
# Saved: ../outputs_deberta/hard/solution-('problem-899', 13).json
# Saved: ../outputs_deberta/hard/solution-('problem-899', 14).json
# Saved: ../outputs_deberta/hard/solution-('problem-9', 0).json
# Saved: ../outputs_deberta/hard/solution-('problem-9', 1).json
# Saved: ../outputs_deberta/hard/solution-('problem-9', 2).json
# Saved: ../outputs_deberta/hard/solution-('problem-9', 3).json
# Saved: ../outputs_deberta/hard/solution-('problem-9', 4).json
# Saved: ../outputs_deberta/hard/solution-('problem-9', 5).json
# Saved: ../outputs_deberta/hard/solution-('problem-9', 6).json
# Saved: ../outputs_deberta/hard/solution-('problem-90', 0).json
# Saved: ../outputs_deberta/hard/solution-('problem-90', 1).json
# Saved: ../outputs_deberta/hard/solution-('problem-90', 2).json
# Saved: ../outputs_deberta/hard/solution-('problem-90', 3).json
# Saved: ../outputs_deberta/hard/solution-('problem-90', 4).json
# Saved: ../outputs_deberta/hard/solution-('problem-90', 5).json
# Saved: ../outputs_deberta/hard/solution-('problem-90', 6).json
# Saved: ../outputs_deberta/hard/solution-('problem-90', 7).json
# Saved: ../outputs_deberta/hard/solution-('problem-90', 8).json
# Saved: ../outputs_deberta/hard/solution-('problem-90', 9).json
# Saved: ../outputs_deberta/hard/solution-('problem-90', 10).json
# Saved: ../outputs_deberta/hard/solution-('problem-90', 11).json
# Saved: ../outputs_deberta/hard/solution-('problem-90', 12).json
# Saved: ../outputs_deberta/hard/solution-('problem-900', 0).json
# Saved: ../outputs_deberta/hard/solution-('problem-900', 1).json
# Saved: ../outputs_deberta/hard/solution-('problem-900', 2).json
# Saved: ../outputs_deberta/hard/solution-('problem-900', 3).json
# Saved: ../outputs_deberta/hard/solution-('problem-900', 4).json
# Saved: ../outputs_deberta/hard/solution-('problem-900', 5).json
# Saved: ../outputs_deberta/hard/solution-('problem-900', 6).json
# Saved: ../outputs_deberta/hard/solution-('problem-900', 7).json
# Saved: ../outputs_deberta/hard/solution-('problem-900', 8).json
# Saved: ../outputs_deberta/hard/solution-('problem-900', 9).json
# Saved: ../outputs_deberta/hard/solution-('problem-900', 10).json
# Saved: ../outputs_deberta/hard/solution-('problem-900', 11).json
# Saved: ../outputs_deberta/hard/solution-('problem-900', 12).json
# Saved: ../outputs_deberta/hard/solution-('problem-900', 13).json
# Saved: ../outputs_deberta/hard/solution-('problem-900', 14).json
# Saved: ../outputs_deberta/hard/solution-('problem-900', 15).json
# Saved: ../outputs_deberta/hard/solution-('problem-900', 16).json
# Saved: ../outputs_deberta/hard/solution-('problem-900', 17).json
# Saved: ../outputs_deberta/hard/solution-('problem-91', 0).json
# Saved: ../outputs_deberta/hard/solution-('problem-91', 1).json
# Saved: ../outputs_deberta/hard/solution-('problem-91', 2).json
# Saved: ../outputs_deberta/hard/solution-('problem-91', 3).json
# Saved: ../outputs_deberta/hard/solution-('problem-91', 4).json
# Saved: ../outputs_deberta/hard/solution-('problem-91', 5).json
# Saved: ../outputs_deberta/hard/solution-('problem-91', 6).json
# Saved: ../outputs_deberta/hard/solution-('problem-91', 7).json
# Saved: ../outputs_deberta/hard/solution-('problem-91', 8).json
# Saved: ../outputs_deberta/hard/solution-('problem-91', 9).json
# Saved: ../outputs_deberta/hard/solution-('problem-91', 10).json
# Saved: ../outputs_deberta/hard/solution-('problem-91', 11).json
# Saved: ../outputs_deberta/hard/solution-('problem-91', 12).json
# Saved: ../outputs_deberta/hard/solution-('problem-91', 13).json
# Saved: ../outputs_deberta/hard/solution-('problem-91', 14).json
# Saved: ../outputs_deberta/hard/solution-('problem-91', 15).json
# Saved: ../outputs_deberta/hard/solution-('problem-92', 0).json
# Saved: ../outputs_deberta/hard/solution-('problem-92', 1).json
# Saved: ../outputs_deberta/hard/solution-('problem-92', 2).json
# Saved: ../outputs_deberta/hard/solution-('problem-92', 3).json
# Saved: ../outputs_deberta/hard/solution-('problem-92', 4).json
# Saved: ../outputs_deberta/hard/solution-('problem-92', 5).json
# Saved: ../outputs_deberta/hard/solution-('problem-92', 6).json
# Saved: ../outputs_deberta/hard/solution-('problem-92', 7).json
# Saved: ../outputs_deberta/hard/solution-('problem-92', 8).json
# Saved: ../outputs_deberta/hard/solution-('problem-92', 9).json
# Saved: ../outputs_deberta/hard/solution-('problem-92', 10).json
# Saved: ../outputs_deberta/hard/solution-('problem-93', 0).json
# Saved: ../outputs_deberta/hard/solution-('problem-93', 1).json
# Saved: ../outputs_deberta/hard/solution-('problem-93', 2).json
# Saved: ../outputs_deberta/hard/solution-('problem-93', 3).json
# Saved: ../outputs_deberta/hard/solution-('problem-93', 4).json
# Saved: ../outputs_deberta/hard/solution-('problem-93', 5).json
# Saved: ../outputs_deberta/hard/solution-('problem-93', 6).json
# Saved: ../outputs_deberta/hard/solution-('problem-93', 7).json
# Saved: ../outputs_deberta/hard/solution-('problem-93', 8).json
# Saved: ../outputs_deberta/hard/solution-('problem-93', 9).json
# Saved: ../outputs_deberta/hard/solution-('problem-93', 10).json
# Saved: ../outputs_deberta/hard/solution-('problem-94', 0).json
# Saved: ../outputs_deberta/hard/solution-('problem-94', 1).json
# Saved: ../outputs_deberta/hard/solution-('problem-94', 2).json
# Saved: ../outputs_deberta/hard/solution-('problem-94', 3).json
# Saved: ../outputs_deberta/hard/solution-('problem-94', 4).json
# Saved: ../outputs_deberta/hard/solution-('problem-94', 5).json
# Saved: ../outputs_deberta/hard/solution-('problem-94', 6).json
# Saved: ../outputs_deberta/hard/solution-('problem-94', 7).json
# Saved: ../outputs_deberta/hard/solution-('problem-94', 8).json
# Saved: ../outputs_deberta/hard/solution-('problem-94', 9).json
# Saved: ../outputs_deberta/hard/solution-('problem-94', 10).json
# Saved: ../outputs_deberta/hard/solution-('problem-94', 11).json
# Saved: ../outputs_deberta/hard/solution-('problem-94', 12).json
# Saved: ../outputs_deberta/hard/solution-('problem-94', 13).json
# Saved: ../outputs_deberta/hard/solution-('problem-94', 14).json
# Saved: ../outputs_deberta/hard/solution-('problem-94', 15).json
# Saved: ../outputs_deberta/hard/solution-('problem-95', 0).json
# Saved: ../outputs_deberta/hard/solution-('problem-95', 1).json
# Saved: ../outputs_deberta/hard/solution-('problem-95', 2).json
# Saved: ../outputs_deberta/hard/solution-('problem-95', 3).json
# Saved: ../outputs_deberta/hard/solution-('problem-95', 4).json
# Saved: ../outputs_deberta/hard/solution-('problem-95', 5).json
# Saved: ../outputs_deberta/hard/solution-('problem-95', 6).json
# Saved: ../outputs_deberta/hard/solution-('problem-95', 7).json
# Saved: ../outputs_deberta/hard/solution-('problem-95', 8).json
# Saved: ../outputs_deberta/hard/solution-('problem-95', 9).json
# Saved: ../outputs_deberta/hard/solution-('problem-95', 10).json
# Saved: ../outputs_deberta/hard/solution-('problem-95', 11).json
# Saved: ../outputs_deberta/hard/solution-('problem-95', 12).json
# Saved: ../outputs_deberta/hard/solution-('problem-95', 13).json
# Saved: ../outputs_deberta/hard/solution-('problem-95', 14).json
# Saved: ../outputs_deberta/hard/solution-('problem-95', 15).json
# Saved: ../outputs_deberta/hard/solution-('problem-95', 16).json
# Saved: ../outputs_deberta/hard/solution-('problem-96', 0).json
# Saved: ../outputs_deberta/hard/solution-('problem-96', 1).json
# Saved: ../outputs_deberta/hard/solution-('problem-96', 2).json
# Saved: ../outputs_deberta/hard/solution-('problem-96', 3).json
# Saved: ../outputs_deberta/hard/solution-('problem-96', 4).json
# Saved: ../outputs_deberta/hard/solution-('problem-96', 5).json
# Saved: ../outputs_deberta/hard/solution-('problem-96', 6).json
# Saved: ../outputs_deberta/hard/solution-('problem-96', 7).json
# Saved: ../outputs_deberta/hard/solution-('problem-96', 8).json
# Saved: ../outputs_deberta/hard/solution-('problem-96', 9).json
# Saved: ../outputs_deberta/hard/solution-('problem-96', 10).json
# Saved: ../outputs_deberta/hard/solution-('problem-96', 11).json
# Saved: ../outputs_deberta/hard/solution-('problem-96', 12).json
# Saved: ../outputs_deberta/hard/solution-('problem-96', 13).json
# Saved: ../outputs_deberta/hard/solution-('problem-96', 14).json
# Saved: ../outputs_deberta/hard/solution-('problem-96', 15).json
# Saved: ../outputs_deberta/hard/solution-('problem-96', 16).json
# Saved: ../outputs_deberta/hard/solution-('problem-96', 17).json
# Saved: ../outputs_deberta/hard/solution-('problem-96', 18).json
# Saved: ../outputs_deberta/hard/solution-('problem-96', 19).json
# Saved: ../outputs_deberta/hard/solution-('problem-96', 20).json
# Saved: ../outputs_deberta/hard/solution-('problem-96', 21).json
# Saved: ../outputs_deberta/hard/solution-('problem-96', 22).json
# Saved: ../outputs_deberta/hard/solution-('problem-96', 23).json
# Saved: ../outputs_deberta/hard/solution-('problem-96', 24).json
# Saved: ../outputs_deberta/hard/solution-('problem-96', 25).json
# Saved: ../outputs_deberta/hard/solution-('problem-97', 0).json
# Saved: ../outputs_deberta/hard/solution-('problem-97', 1).json
# Saved: ../outputs_deberta/hard/solution-('problem-97', 2).json
# Saved: ../outputs_deberta/hard/solution-('problem-97', 3).json
# Saved: ../outputs_deberta/hard/solution-('problem-97', 4).json
# Saved: ../outputs_deberta/hard/solution-('problem-97', 5).json
# Saved: ../outputs_deberta/hard/solution-('problem-97', 6).json
# Saved: ../outputs_deberta/hard/solution-('problem-97', 7).json
# Saved: ../outputs_deberta/hard/solution-('problem-97', 8).json
# Saved: ../outputs_deberta/hard/solution-('problem-97', 9).json
# Saved: ../outputs_deberta/hard/solution-('problem-97', 10).json
# Saved: ../outputs_deberta/hard/solution-('problem-97', 11).json
# Saved: ../outputs_deberta/hard/solution-('problem-98', 0).json
# Saved: ../outputs_deberta/hard/solution-('problem-98', 1).json
# Saved: ../outputs_deberta/hard/solution-('problem-98', 2).json
# Saved: ../outputs_deberta/hard/solution-('problem-98', 3).json
# Saved: ../outputs_deberta/hard/solution-('problem-98', 4).json
# Saved: ../outputs_deberta/hard/solution-('problem-98', 5).json
# Saved: ../outputs_deberta/hard/solution-('problem-98', 6).json
# Saved: ../outputs_deberta/hard/solution-('problem-98', 7).json
# Saved: ../outputs_deberta/hard/solution-('problem-98', 8).json
# Saved: ../outputs_deberta/hard/solution-('problem-98', 9).json
# Saved: ../outputs_deberta/hard/solution-('problem-98', 10).json
# Saved: ../outputs_deberta/hard/solution-('problem-98', 11).json
# Saved: ../outputs_deberta/hard/solution-('problem-99', 0).json
# Saved: ../outputs_deberta/hard/solution-('problem-99', 1).json
# Saved: ../outputs_deberta/hard/solution-('problem-99', 2).json
# Saved: ../outputs_deberta/hard/solution-('problem-99', 3).json
# Saved: ../outputs_deberta/hard/solution-('problem-99', 4).json
# Saved: ../outputs_deberta/hard/solution-('problem-99', 5).json
# Saved: ../outputs_deberta/hard/solution-('problem-99', 6).json
# Saved: ../outputs_deberta/hard/solution-('problem-99', 7).json
# Saved: ../outputs_deberta/hard/solution-('problem-99', 8).json
# Saved: ../outputs_deberta/hard/solution-('problem-99', 9).json
# Saved: ../outputs_deberta/hard/solution-('problem-99', 10).json
# Saved: ../outputs_deberta/hard/solution-('problem-99', 11).json
# Saved: ../outputs_deberta/hard/solution-('problem-99', 12).json
# Saved: ../outputs_deberta/hard/solution-('problem-99', 13).json
# Combined Metrics Across All Levels:
# Classification Report:
#                precision    recall  f1-score   support
#
# No Change (0)       0.92      0.96      0.94     26797
#    Change (1)       0.82      0.68      0.74      6857
#
#      accuracy                           0.90     33654
#     macro avg       0.87      0.82      0.84     33654
#  weighted avg       0.90      0.90      0.90     33654
# ('../models/tokenizer_config.json',
#  '../models/special_tokens_map.json',
#  '../models/spm.model',
#  '../models/added_tokens.json',
#  '../models/tokenizer.json')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil

# Specify the source folder (in Colab environment)
source_folder = '../outputs_deberta'  # Replace with your folder path

# Specify the destination in Google Drive
destination_folder = '/content/drive/MyDrive/LLM/output'  # Replace with desired path in Drive

# Move the folder
shutil.move(source_folder, destination_folder)
# Out:
# '/content/drive/MyDrive/LLM/output'

# %%
import os
import json
from collections import defaultdict

def extract_problem_number_and_index(filename):
    # Extract the problem number and index from the filename
    parts = filename.split('-')[2].split(',')
    problem_number = parts[0].strip("('_")
    index = int(parts[1].strip(") .json"))
    return problem_number, index

def create_folder_if_not_exists(folder_path):
    os.makedirs(folder_path, exist_ok=True)

def merge_files(input_directory, output_directory):
    create_folder_if_not_exists(output_directory)
    problem_files = defaultdict(list)

    for filename in os.listdir(input_directory):
        if filename.startswith('solution-') and filename.endswith('.json'):
            problem_number, index = extract_problem_number_and_index(filename)
            problem_files[problem_number].append((index, filename))

